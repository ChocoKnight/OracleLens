# %% [markdown]
# ### Get CSV Files

# %%
import os

current_directory = os.getcwd()
csv_files = [file for file in os.listdir(current_directory) if file.endswith('.csv')]
csv_files
# Out:
# ['2014_LoL_esports_match_data_from_OraclesElixir.csv',
#  '2015_LoL_esports_match_data_from_OraclesElixir.csv',
#  '2016_LoL_esports_match_data_from_OraclesElixir.csv',
#  '2017_LoL_esports_match_data_from_OraclesElixir.csv',
#  '2018_LoL_esports_match_data_from_OraclesElixir.csv',
#  '2019_LoL_esports_match_data_from_OraclesElixir.csv',
#  '2020_LoL_esports_match_data_from_OraclesElixir.csv',
#  '2021_LoL_esports_match_data_from_OraclesElixir.csv',
#  '2022_LoL_esports_match_data_from_OraclesElixir.csv',
#  '2023_LoL_esports_match_data_from_OraclesElixir.csv',
#  '2024_LoL_esports_match_data_from_OraclesElixir.csv',
#  '2025_LoL_esports_match_data_from_OraclesElixir.csv']

# %% [markdown]
# ### Turn to Dataframes and Preprocess

# %%
import numpy as np
import pandas as pd
import DataClasses as dc

# %%
def get_dataframe(csv_file: str) -> pd.DataFrame:
    df = pd.read_csv(csv_file)
    df = df[df['datacompleteness'] == 'complete']

    relevant_features = ['gameid', 'league', 'year', 'split', 'playoffs', 'date', 'game', 'patch', 'side', 'position', 'playername', 'teamname', 'champion', 'ban1', 'ban2', 'ban3', 'ban4', 'ban5', 'pick1', 'pick2', 'pick3', 'pick4', 'pick5', 'gamelength', 'result', 'kills', 'deaths', 
                         'assists', 'firstblood', 'firstdragon', 'dragons', 'infernals', 'mountains', 'clouds', 'oceans', 'chemtechs', 'hextechs', 'dragons (type unknown)', 'elders', 'firstherald', 'heralds', 'void_grubs', 'firstbaron', 
                         'barons', 'firsttower', 'towers', 'turretplates', 'inhibitors', 'damagetochampions', 'wardsplaced', 'wardskilled', 'controlwardsbought', 'visionscore', 'totalgold', 'goldspent', 'total cs', 'goldat15', 'killsat15', 'assistsat15', 'deathsat15']
    
    df = df[relevant_features]
    return df

# %% [markdown]
# ### Going Through Data

# %%
import math

def get_tournaments(df: pd.DataFrame):
    df_tour = df[['league', 'year', 'split']]
    df_tour = df_tour.drop_duplicates().reset_index(drop=True)

    tournaments = []

    for row in df_tour.itertuples():
        tournament = dc.Tournament(row[1], row[2], row[3])
        tournament.fix_split()
        tournaments.append(tournament)

    return tournaments

def get_teams(df: pd.DataFrame):
    df_teams = df[['teamname', 'year']]
    df_teams = df_teams.drop_duplicates().reset_index(drop=True)

    teams = []

    for row in df_teams.itertuples():
        team = dc.Team(row[1], row[2])
        team.fix_name()
        teams.append(team)

    return teams

def get_players(df: pd.DataFrame):
    df_players = df[['position', 'playername', 'teamname', 'year']]
    df_players = df_players.drop_duplicates().reset_index(drop=True)

    players = []

    for row in df_players.itertuples():
        if row[1] == 'team':
            continue

        team = dc.Team(row[3], row[4])
        team.fix_name()

        player = dc.Player(row[2], team)
        player.fix_name()
        players.append(player)

    return players

def get_objectives(df: pd.DataFrame):
    df_objectives = df[df['position'] == 'team'][['side', 'firstblood', 'firsttower', 'towers', 'turretplates', 'void_grubs', 'heralds', 'barons', 'infernals', 'mountains', 'clouds', 'oceans', 'hextechs', 'chemtechs', 'elders']]
    
    blue_objectives = None
    red_objectives = None

    for row in df_objectives.itertuples():
        objectives = dc.Objectives(row[2], row[3], row[4], row[5], row[6], row[7], row[8], row[9], row[10], row[11], row[12], row[13], row[14], row[15], False, 0, 0)
        objectives.fix_objectives()
        if row[1] == 'Blue':
            blue_objectives = objectives
        else:
            red_objectives = objectives

    return (blue_objectives, red_objectives)


def get_pick_bans(df: pd.DataFrame):
    df_pick_bans = df[df['position'] == 'team'][['side', 'ban1', 'ban2', 'ban3', 'ban4', 'ban5', 'pick1', 'pick2', 'pick3', 'pick4', 'pick5']]
    
    blue_pick_bans = None 
    red_pick_bans = None 

    for row in df_pick_bans.itertuples():
        pick_bans = dc.PickBan(row[2], row[3], row[4], row[5], row[6], row[7], row[8], row[9], row[10], row[11])
        pick_bans.check_existing_champions()
        
        if row[1] == 'Blue':
            blue_pick_bans = pick_bans
        else:
            red_pick_bans = pick_bans

    return (blue_pick_bans, red_pick_bans)

def get_player_performances(df: pd.DataFrame):
    df_players = df[df['position'] != 'team'][['side', 'playername', 'position', 'champion', 'kills', 'deaths', 'assists', 
                     'damagetochampions', 'wardsplaced', 'wardskilled', 'controlwardsbought', 'visionscore', 
                     'totalgold', 'goldspent', 'total cs', 'killsat15','deathsat15', 'assistsat15','goldat15',
                     'teamname', 'year']]
    
    blue_player_performances = []
    red_player_performances = []

    for row in df_players.itertuples():
        team = dc.Team(row[20], row[21])
        team.fix_name()
        player = dc.Player(row[2], team)
        player.fix_name()
        player_performance = dc.PlayerPerformance(player, row[3], row[4], row[5], 
                                                  row[6], row[7], row[8], row[9], row[10], row[11], row[12], row[13], 
                                                  row[14], row[15], row[16], row[17], row[18], row[19])
        player_performance.set_15_stats()
        player_performance.fix_stats()
        if row[1] == 'Blue':
            blue_player_performances.append(player_performance)
        else:
            red_player_performances.append(player_performance)

    return (blue_player_performances, red_player_performances)

def get_game(df: pd.DataFrame):
    df_game = df[df['position'] == 'team'][['game', 'side', 'position', 'teamname', 'year', 'gamelength', 'result']]

    blue_pb, red_pb = get_pick_bans(df)
    blue_obj, red_obj = get_objectives(df)
    blue_pp, red_pp = get_player_performances(df)

    blue_team = dc.Team(df_game[df_game['side'] == 'Blue']['teamname'].iloc[0], df_game[df_game['side'] == 'Blue']['year'].iloc[0])
    blue_team.fix_name()
    red_team = dc.Team(df_game[df_game['side'] == 'Red']['teamname'].iloc[0], df_game[df_game['side'] == 'Red']['year'].iloc[0])
    red_team.fix_name()

    duration = df_game['gamelength'].iloc[0]

    number = df_game['game'].iloc[0]

    blue_win = df_game[df_game['side'] == 'Blue']['result'].iloc[0]

    # game = dc.Game(number, blue_team, red_team, blue_win, blue_pb, red_pb, blue_obj, red_obj, blue_pp, red_pp, duration)
    # print(game)
    # print(df_game)
    # print(df_game[df_game['side'] == 'Blue']['year'].iloc[0])

    return dc.Game(number, blue_team, red_team, blue_win, blue_pb, red_pb, blue_obj, red_obj, blue_pp, red_pp, duration)

# Only insert tournament dfs 
def get_matches(df: pd.DataFrame):
    matches = []
    currentMatch = None

    df_matches = df[df['position'] == 'team'][['gameid', 'playoffs', 'date', 'game', 'patch', 'teamname', 'year']]

    # print(df_matches)

    for row in df_matches.itertuples():
        if row[4] == 1 or currentMatch is None:
            if currentMatch is not None:
                matches.append(currentMatch)
                # print(row[3].split()[0])
            
            currentMatch = dc.Match(date = row[3].split()[0], playoffs=row[2], patch=row[5])
            currentMatch.fix_patch()
            # print(type(row[5]), row[5], currentMatch.patch)
            teamOne = dc.Team(df_matches[(df_matches['gameid'] == row[1]) & (df_matches['game'] == row[4])]['teamname'].iloc[0], df_matches[(df_matches['gameid'] == row[1]) & (df_matches['game'] == row[4])]['year'].iloc[0])
            teamOne.fix_name()
            currentMatch.teamOne = teamOne
            teamTwo = dc.Team(df_matches[(df_matches['gameid'] == row[1]) & (df_matches['game'] == row[4])]['teamname'].iloc[1], df_matches[(df_matches['gameid'] == row[1]) & (df_matches['game'] == row[4])]['year'].iloc[0])
            teamTwo.fix_name()
            currentMatch.teamTwo = teamTwo 

        currentMatch.games.append(get_game(df[df['gameid'] == row[1]]))

    return matches

# %%
df_2024 = get_dataframe(csv_files[0])
# test = df_2024[df_2024['position'] == 'team'][['gameid', 'league', 'year', 'split', 'playoffs', 'date', 'game', 'patch', 'teamname']]
# test[test['league'] == 'LCK'].head(10)

tournament_df = df_2024[df_2024['league'] == 'EU CS']
tournament_df = tournament_df[tournament_df['year'] == 2014]
get_matches(tournament_df)

# tournament_df[tournament_df['position'] == 'team'][['gameid', 'league', 'year', 'split', 'playoffs', 'date', 'game', 'patch', 'teamname']].head(10)

# get_game(df_2024[df_2024['gameid'] == 'LOLTMNT03_183544'])
# # type(df_2024[df_2024['gameid'] == 'LOLTMNT03_183544'][df_2024['position'] == 'team'][['game', 'year', 'side', 'position', 'teamname', 'year', 'gamelength', 'result']][df_2024['side'] == 'Blue']['teamname'].iloc[0])
# type(df_2024[df_2024['side'] == 'Blue']['year'].iloc[0])
# Out:
# [<DataClasses.Match at 0x19cd638e600>,
#  <DataClasses.Match at 0x19cd638e450>,
#  <DataClasses.Match at 0x19cd638e7b0>,
#  <DataClasses.Match at 0x19cd638e2a0>,
#  <DataClasses.Match at 0x19cd644dca0>,
#  <DataClasses.Match at 0x19cd644eb40>,
#  <DataClasses.Match at 0x19cd629f860>,
#  <DataClasses.Match at 0x19cb7129550>,
#  <DataClasses.Match at 0x19cd644ecc0>,
#  <DataClasses.Match at 0x19cd64269f0>,
#  <DataClasses.Match at 0x19cd6427bf0>,
#  <DataClasses.Match at 0x19cd6426e40>,
#  <DataClasses.Match at 0x19cd5679040>,
#  <DataClasses.Match at 0x19cd6427a70>,
#  <DataClasses.Match at 0x19cd6458f50>,
#  <DataClasses.Match at 0x19cd64594c0>,
#  <DataClasses.Match at 0x19cd6426c30>,
#  <DataClasses.Match at 0x19cd645a540>,
#  <DataClasses.Match at 0x19cd63d2a50>,
#  <DataClasses.Match at 0x19cd6431130>,
#  <DataClasses.Match at 0x19cd6469eb0>,
#  <DataClasses.Match at 0x19cd63d2f90>,
#  <DataClasses.Match at 0x19cd62c17f0>,
#  <DataClasses.Match at 0x19cd6468380>,
#  <DataClasses.Match at 0x19cd64591c0>,
#  <DataClasses.Match at 0x19cd646bb00>,
#  <DataClasses.Match at 0x19cb71514c0>,
#  <DataClasses.Match at 0x19cd6468620>,
#  <DataClasses.Match at 0x19cd744f590>,
#  <DataClasses.Match at 0x19cd7467620>,
#  <DataClasses.Match at 0x19cd7494ce0>,
#  <DataClasses.Match at 0x19cd744b5c0>,
#  <DataClasses.Match at 0x19cd56b9c10>,
#  <DataClasses.Match at 0x19cd7449400>,
#  <DataClasses.Match at 0x19cd744a150>,
#  <DataClasses.Match at 0x19cd74a1b20>,
#  <DataClasses.Match at 0x19cd7497aa0>,
#  <DataClasses.Match at 0x19cd74a1f70>,
#  <DataClasses.Match at 0x19cd7494590>,
#  <DataClasses.Match at 0x19cd56b9a90>,
#  <DataClasses.Match at 0x19cd5b01880>,
#  <DataClasses.Match at 0x19cd7492f90>,
#  <DataClasses.Match at 0x19cd7492030>,
#  <DataClasses.Match at 0x19cd74c5310>,
#  <DataClasses.Match at 0x19cd74c4710>,
#  <DataClasses.Match at 0x19cd74cbc80>,
#  <DataClasses.Match at 0x19cd7495a30>,
#  <DataClasses.Match at 0x19cd7492120>,
#  <DataClasses.Match at 0x19cd74c7dd0>,
#  <DataClasses.Match at 0x19cd5721fa0>,
#  <DataClasses.Match at 0x19cd74c8140>,
#  <DataClasses.Match at 0x19cd74c5700>,
#  <DataClasses.Match at 0x19cd5721f70>,
#  <DataClasses.Match at 0x19cd74d5460>,
#  <DataClasses.Match at 0x19cd5721ee0>,
#  <DataClasses.Match at 0x19cd5d99f10>,
#  <DataClasses.Match at 0x19cd74df710>,
#  <DataClasses.Match at 0x19cd74dc410>,
#  <DataClasses.Match at 0x19cd6206c90>,
#  <DataClasses.Match at 0x19cd74de780>,
#  <DataClasses.Match at 0x19cd74d4e60>,
#  <DataClasses.Match at 0x19cd750ade0>,
#  <DataClasses.Match at 0x19cd5631cd0>,
#  <DataClasses.Match at 0x19cd751f020>,
#  <DataClasses.Match at 0x19cd751efc0>,
#  <DataClasses.Match at 0x19cd74df6b0>,
#  <DataClasses.Match at 0x19cd7533980>,
#  <DataClasses.Match at 0x19cd74d79e0>,
#  <DataClasses.Match at 0x19cd7546450>]

# %%
df_2024 = get_dataframe(csv_files[-1])
tournaments_2024 = get_tournaments(df_2024)
teams_2024 = get_teams(df_2024)
players_2024 = get_players(df_2024)

ppb_2024, ppr_2024 = get_player_performances(df_2024[df_2024['gameid'] == 'LOLTMNT03_183544'])

for tournament in tournaments_2024:
    print(tournament)
    tournament_df = df_2024[df_2024['league'] == tournament.league]
    tournament_df = tournament_df[tournament_df['year'] == tournament.year]
    tournament_df = tournament_df[tournament_df['split'] == tournament.split]

    print(tournament_df)

    tournament.matches = get_matches(tournament_df)
    break
# for team in teams_2024:
#     print(team)
# for player in players_2024:
#     print(player)
# for player in ppb_2024:
#     print(player)
# # ppb_2024
# Out:
# C:\Users\ktann\AppData\Local\Temp\ipykernel_22052\3123184168.py:2: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(csv_file)
# LFL2 2025 - Winter
#                  gameid league  year   split  playoffs                 date  \
# 0      LOLTMNT03_179647   LFL2  2025  Winter         0  2025-01-11 11:11:24
# 1      LOLTMNT03_179647   LFL2  2025  Winter         0  2025-01-11 11:11:24
# 2      LOLTMNT03_179647   LFL2  2025  Winter         0  2025-01-11 11:11:24
# 3      LOLTMNT03_179647   LFL2  2025  Winter         0  2025-01-11 11:11:24
# 4      LOLTMNT03_179647   LFL2  2025  Winter         0  2025-01-11 11:11:24
# ...                 ...    ...   ...     ...       ...                  ...
# 21199  LOLTMNT06_107351   LFL2  2025  Winter         1  2025-03-09 14:24:44
# 21200  LOLTMNT06_107351   LFL2  2025  Winter         1  2025-03-09 14:24:44
# 21201  LOLTMNT06_107351   LFL2  2025  Winter         1  2025-03-09 14:24:44
# 21202  LOLTMNT06_107351   LFL2  2025  Winter         1  2025-03-09 14:24:44
# 21203  LOLTMNT06_107351   LFL2  2025  Winter         1  2025-03-09 14:24:44
#
#        game  patch  side position  ... wardskilled controlwardsbought  \
# 0         1  15.01  Blue      top  ...           2                  3
# 1         1  15.01  Blue      jng  ...           7                  6
# 2         1  15.01  Blue      mid  ...           3                  4
# 3         1  15.01  Blue      bot  ...           2                  1
# 4         1  15.01  Blue      sup  ...          10                  9
# ...     ...    ...   ...      ...  ...         ...                ...
# 21199     5  15.04   Red      mid  ...           2                  0
# 21200     5  15.04   Red      bot  ...           8                  1
# 21201     5  15.04   Red      sup  ...          14                  1
# 21202     5  15.04  Blue     team  ...          37                 32
# 21203     5  15.04   Red     team  ...          42                  2
#
#       visionscore totalgold goldspent total cs goldat15 killsat15 assistsat15  \
# 0              17     10668      9793    234.0   4531.0       0.0         0.0
# 1              29      7429      7200    143.0   4461.0       0.0         0.0
# 2              20      9032      8050    209.0   4581.0       0.0         0.0
# 3              10      9407      8925    251.0   4687.0       0.0         0.0
# 4              82      5719      4825     38.0   3238.0       0.0         0.0
# ...           ...       ...       ...      ...      ...       ...         ...
# 21199          25     12312     11850    279.0   5223.0       1.0         1.0
# 21200          31     14319     14375    309.0   4835.0       0.0         2.0
# 21201         102      8822     10100     47.0   3772.0       0.0         2.0
# 21202         289     67545     59450      NaN  24713.0       5.0        11.0
# 21203         220     58859     58941      NaN  23273.0       3.0         6.0
#
#       deathsat15
# 0            1.0
# 1            0.0
# 2            1.0
# 3            0.0
# 4            1.0
# ...          ...
# 21199        0.0
# 21200        1.0
# 21201        1.0
# 21202        3.0
# 21203        5.0
#
# [876 rows x 60 columns]

# %% [markdown]
# ### Extracting Needed Data Test

# %%
for csv in csv_files:
    df = get_dataframe(csv)
    tournaments = get_tournaments(df)
    teams = get_teams(df)
    players = get_players(df)

    for tournament in tournaments:
        tournament_df = df[df['league'] == tournament.league]
        tournament_df = tournament_df[tournament_df['year'] == tournament.year]
        tournament_df = tournament_df[tournament_df['split'] == tournament.split]

        tournament.matches = get_matches(tournament_df)

        print(tournament)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[43], line 12
#       9 tournament_df = tournament_df[tournament_df['year'] == tournament.year]
#      10 tournament_df = tournament_df[tournament_df['split'] == tournament.split]
# ---> 12 tournament.matches = get_matches(tournament_df)
#      14 print(tournament)
#
# Cell In[37], line 158, in get_matches(df)
#     155         teamTwo.fix_name()
#     156         currentMatch.teamTwo = teamTwo
# --> 158     currentMatch.games.append(get_game(df[df['gameid'] == row[1]]))
#     160 return matches
#
# File c:\Users\ktann\Documents\College\Cal Poly Slo\4. Senior Year\Senior Project\.venv\Lib\site-packages\pandas\core\frame.py:4093, in DataFrame.__getitem__(self, key)
#    4091 # Do we have a (boolean) 1d indexer?
#    4092 if com.is_bool_indexer(key):
# -> 4093     return self._getitem_bool_array(key)
#    4095 # We are left with two options: a single key, and a collection of keys,
#    4096 # We interpret tuples as collections only for non-MultiIndex
#    4097 is_single_key = isinstance(key, tuple) or not is_list_like(key)
#
# File c:\Users\ktann\Documents\College\Cal Poly Slo\4. Senior Year\Senior Project\.venv\Lib\site-packages\pandas\core\frame.py:4155, in DataFrame._getitem_bool_array(self, key)
#    4152     return self.copy(deep=None)
#    4154 indexer = key.nonzero()[0]
# -> 4155 return self._take_with_is_copy(indexer, axis=0)
#
# File c:\Users\ktann\Documents\College\Cal Poly Slo\4. Senior Year\Senior Project\.venv\Lib\site-packages\pandas\core\generic.py:4153, in NDFrame._take_with_is_copy(self, indices, axis)
#    4142 @final
#    4143 def _take_with_is_copy(self, indices, axis: Axis = 0) -> Self:
#    4144     """
#    4145     Internal version of the `take` method that sets the `_is_copy`
#    4146     attribute to keep track of the parent dataframe (using in indexing
#    (...)
#    4151     See the docstring of `take` for full explanation of the parameters.
#    4152     """
# -> 4153     result = self.take(indices=indices, axis=axis)
#    4154     # Maybe set copy if we didn't actually change the index.
#    4155     if self.ndim == 2 and not result._get_axis(axis).equals(self._get_axis(axis)):
#
# File c:\Users\ktann\Documents\College\Cal Poly Slo\4. Senior Year\Senior Project\.venv\Lib\site-packages\pandas\core\generic.py:4133, in NDFrame.take(self, indices, axis, **kwargs)
#    4128     # We can get here with a slice via DataFrame.__getitem__
#    4129     indices = np.arange(
#    4130         indices.start, indices.stop, indices.step, dtype=np.intp
#    4131     )
# -> 4133 new_data = self._mgr.take(
#    4134     indices,
#    4135     axis=self._get_block_manager_axis(axis),
#    4136     verify=True,
#    4137 )
#    4138 return self._constructor_from_mgr(new_data, axes=new_data.axes).__finalize__(
#    4139     self, method="take"
#    4140 )
#
# File c:\Users\ktann\Documents\College\Cal Poly Slo\4. Senior Year\Senior Project\.venv\Lib\site-packages\pandas\core\internals\managers.py:894, in BaseBlockManager.take(self, indexer, axis, verify)
#     891 indexer = maybe_convert_indices(indexer, n, verify=verify)
#     893 new_labels = self.axes[axis].take(indexer)
# --> 894 return self.reindex_indexer(
#     895     new_axis=new_labels,
#     896     indexer=indexer,
#     897     axis=axis,
#     898     allow_dups=True,
#     899     copy=None,
#     900 )
#
# File c:\Users\ktann\Documents\College\Cal Poly Slo\4. Senior Year\Senior Project\.venv\Lib\site-packages\pandas\core\internals\managers.py:688, in BaseBlockManager.reindex_indexer(self, new_axis, indexer, axis, fill_value, allow_dups, copy, only_slice, use_na_proxy)
#     680     new_blocks = self._slice_take_blocks_ax0(
#     681         indexer,
#     682         fill_value=fill_value,
#     683         only_slice=only_slice,
#     684         use_na_proxy=use_na_proxy,
#     685     )
#     686 else:
#     687     new_blocks = [
# --> 688         blk.take_nd(
#     689             indexer,
#     690             axis=1,
#     691             fill_value=(
#     692                 fill_value if fill_value is not None else blk.fill_value
#     693             ),
#     694         )
#     695         for blk in self.blocks
#     696     ]
#     698 new_axes = list(self.axes)
#     699 new_axes[axis] = new_axis
#
# File c:\Users\ktann\Documents\College\Cal Poly Slo\4. Senior Year\Senior Project\.venv\Lib\site-packages\pandas\core\internals\blocks.py:1307, in Block.take_nd(self, indexer, axis, new_mgr_locs, fill_value)
#    1304     allow_fill = True
#    1306 # Note: algos.take_nd has upcast logic similar to coerce_to_target_dtype
# -> 1307 new_values = algos.take_nd(
#    1308     values, indexer, axis=axis, allow_fill=allow_fill, fill_value=fill_value
#    1309 )
#    1311 # Called from three places in managers, all of which satisfy
#    1312 #  these assertions
#    1313 if isinstance(self, ExtensionBlock):
#    1314     # NB: in this case, the 'axis' kwarg will be ignored in the
#    1315     #  algos.take_nd call above.
#
# File c:\Users\ktann\Documents\College\Cal Poly Slo\4. Senior Year\Senior Project\.venv\Lib\site-packages\pandas\core\array_algos\take.py:117, in take_nd(arr, indexer, axis, fill_value, allow_fill)
#     114     return arr.take(indexer, fill_value=fill_value, allow_fill=allow_fill)
#     116 arr = np.asarray(arr)
# --> 117 return _take_nd_ndarray(arr, indexer, axis, fill_value, allow_fill)
#
# File c:\Users\ktann\Documents\College\Cal Poly Slo\4. Senior Year\Senior Project\.venv\Lib\site-packages\pandas\core\array_algos\take.py:157, in _take_nd_ndarray(arr, indexer, axis, fill_value, allow_fill)
#     155     out = np.empty(out_shape, dtype=dtype, order="F")
#     156 else:
# --> 157     out = np.empty(out_shape, dtype=dtype)
#     159 func = _get_take_nd_function(
#     160     arr.ndim, arr.dtype, out.dtype, axis=axis, mask_info=mask_info
#     161 )
#     162 func(arr, indexer, out, fill_value)
#
# KeyboardInterrupt:

# %%
# for i in teams:
#     print(i)

# %% [markdown]
# ### Connecting to DB

# %%
# %pip install mysql-connector-python
# %pip install python-dotenv

# %%
import mysql.connector
import os
from dotenv import load_dotenv

load_dotenv()

database = mysql.connector.connect(
  host="localhost",
  user="root",
  password= os.getenv('mysql_password'),
  database = 'league_of_legends_esports'
)

if database.is_connected():
    print(f"Connected to db")
else:
    print(f"Failed to connect to db")
# Out:
# Connected to db

# %%
db_cursor = database.cursor()

db_cursor.execute("SHOW DATABASES")

for x in db_cursor:
  print(x)
# Out:
# ('information_schema',)
# ('league_of_legends_esports',)
# ('mysql',)
# ('performance_schema',)
# ('sakila',)
# ('sys',)
# ('world',)

# %% [markdown]
# ### Disconnecting to DB

# %%
database.close()

# %% [markdown]
# ### Adding to DB

# %% [markdown]
# #### SQL Statements

# %%
# Teams
insert_team = '''INSERT INTO teams (name, year) VALUES (%s, %s)'''
team_count = '''SELECT COUNT(*) FROM teams WHERE name = %s AND year = %s'''
team_id = '''SELECT id FROM teams WHERE name = %s AND year = %s'''

# %%
# Players
insert_player = '''INSERT INTO players (name, team) VALUES (%s, %s)'''
player_count = '''SELECT COUNT(*) FROM players WHERE name = %s AND team = %s'''
player_id = '''SELECT id FROM players WHERE name = %s AND team = %s'''

# %%
# Tournaments 
insert_tournament = '''INSERT INTO tournaments (league, year, split) VALUES (%s, %s, %s)'''
tournament_count = '''SELECT COUNT(*) FROM tournaments WHERE league = %s AND year = %s AND split = %s'''
tournament_id = '''SELECT id FROM tournaments WHERE league = %s AND year = %s AND split = %s'''

# %%
# Matches
insert_match = '''INSERT INTO matches (tournament_id, date, team_one, team_two, playoffs, patch) VALUES (%s, %s, %s, %s, %s, %s)'''
match_count = '''SELECT COUNT(*) FROM matches WHERE tournament_id = %s AND date = %s AND team_one = %s AND team_two = %s AND playoffs = %s AND patch = %s'''
match_id = '''SELECT id FROM matches WHERE tournament_id = %s AND date = %s AND team_one = %s AND team_two = %s AND playoffs = %s AND patch = %s'''

# %%
# Games
insert_game = '''INSERT INTO games (match_id, game_number, blue_team, red_team, blue_win, duration) VALUES (%s, %s, %s, %s, %s, %s)'''
game_count = '''SELECT COUNT(*) FROM games WHERE match_id = %s AND game_number = %s AND blue_team = %s AND red_team = %s AND blue_win = %s AND duration = %s'''
game_id = '''SELECT id FROM games WHERE match_id = %s AND game_number = %s AND blue_team = %s AND red_team = %s AND blue_win = %s AND duration = %s'''

# %%
# Objectives
insert_objective = '''
INSERT INTO 
objectives (game_id, side, first_blood, first_tower, towers, tower_plates, void_grubs, rift_heralds, baron_nashors, infernals, mountains, clouds, oceans, hextechs, chemtechs, elders, feats_of_strength, ruinous_atakhan, voracious_atakhan) 
VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)'''

objective_count = '''SELECT COUNT(*) FROM objectives WHERE game_id = %s AND side = %s AND first_blood = %s AND first_tower = %s AND towers = %s AND tower_plates = %s AND void_grubs = %s AND rift_heralds = %s AND baron_nashors = %s AND infernals = %s AND mountains = %s AND clouds = %s AND oceans = %s AND hextechs = %s AND chemtechs = %s AND elders = %s AND feats_of_strength = %s AND ruinous_atakhan = %s AND voracious_atakhan = %s'''

# %%
# Pick Bans
# insert_pick_ban = '''INSERT INTO pick_bans (game_id, side, ban1, ban2, ban3, ban4, ban5, pick1, pick2, pick3, pick4, pick5) 
# VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)'''
# pick_ban_count = '''SELECT COUNT(*) FROM pick_bans WHERE game_id = %s AND side = %s'''

insert_pick_ban = '''Insert into pick_bans (game_id, side, pick_ban, order_number, champion) VALUES (%s, %s, %s, %s, %s)'''
pick_ban_count = '''SELECT COUNT(*) FROM pick_bans WHERE game_id = %s AND side = %s AND pick_ban = %s AND order_number = %s'''

# %%
# Player Performances
insert_player_performance = '''INSERT INTO player_performances (game_id, player_id, role, champion, kills, deaths, assists, damage_to_champions, wards_placed, wards_destroyed, control_wards_bought, vision_score, total_gold, gold_spent, creep_score, kills_at_15, deaths_at_15, assists_at_15, gold_at_15)
VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)'''

# player_performance_count = '''SELECT COUNT(*) FROM player_performances WHERE game_id = %s AND player_id = %s AND role = %s AND champion = %s AND kills = %s AND deaths = %s AND assists = %s AND damage_to_champions = %s AND wards_placed = %s AND wards_destroyed = %s AND control_wards_bought = %s AND vision_score = %s AND total_gold = %s AND gold_spent = %s AND creep_score = %s AND kills_at_15 = %s AND deaths_at_15 = %s AND assists_at_15 = %s AND gold_at_15 = %s'''
player_performance_count = '''SELECT COUNT(*) FROM player_performances WHERE game_id = %s AND player_id = %s AND role = %s AND champion = %s'''

# %% [markdown]
# #### Script

# %%
csv_files
# Out:
# ['2014_LoL_esports_match_data_from_OraclesElixir.csv',
#  '2015_LoL_esports_match_data_from_OraclesElixir.csv',
#  '2016_LoL_esports_match_data_from_OraclesElixir.csv',
#  '2017_LoL_esports_match_data_from_OraclesElixir.csv',
#  '2018_LoL_esports_match_data_from_OraclesElixir.csv',
#  '2019_LoL_esports_match_data_from_OraclesElixir.csv',
#  '2020_LoL_esports_match_data_from_OraclesElixir.csv',
#  '2021_LoL_esports_match_data_from_OraclesElixir.csv',
#  '2022_LoL_esports_match_data_from_OraclesElixir.csv',
#  '2023_LoL_esports_match_data_from_OraclesElixir.csv',
#  '2024_LoL_esports_match_data_from_OraclesElixir.csv',
#  '2025_LoL_esports_match_data_from_OraclesElixir.csv']

# %% [markdown]
# ##### Test

# %%
for csv in csv_files[9:10]:
    df = get_dataframe(csv)
    tournaments = get_tournaments(df)
    teams = get_teams(df)
    players = get_players(df)
    
    for player in players:
        print(player)
    break

    year_teams = {}
    year_players = {}

    for team in teams:
        db_cursor.execute(team_count, (team.name, team.year))
        if db_cursor.fetchone()[0] == 0:
            db_cursor.execute(insert_team, (team.name, team.year))
            database.commit()

        print(team)

        db_cursor.execute(team_id, (team.name, team.year))
        year_teams[team.name] = db_cursor.fetchone()[0]

# %% [markdown]
# ##### Actual

# %%
db_cursor = database.cursor()
# for csv in csv_files:
for csv in csv_files[11:12]:
    df = get_dataframe(csv)
    tournaments = get_tournaments(df)
    teams = get_teams(df)
    players = get_players(df)

    for tournament in tournaments:
        tournament_df = df[df['league'] == tournament.league]
        tournament_df = tournament_df[tournament_df['year'] == tournament.year]
        tournament_df = tournament_df[tournament_df['split'] == tournament.split]

        print(tournament)
        tournament.matches = get_matches(tournament_df)

    year_teams = {}
    year_players = {}

    for team in teams:
        # print(team)
        db_cursor.execute(team_count, (team.name, team.year))
        if db_cursor.fetchone()[0] == 0:
            db_cursor.execute(insert_team, (team.name, team.year))
            database.commit()

        db_cursor.execute(team_id, (team.name, team.year))
        year_teams[team.name] = db_cursor.fetchone()[0]

    for player in players:
        # print(player)
        db_cursor.execute(team_id, (player.team.name, player.team.year))
        player_team_id = db_cursor.fetchone()[0]

        # print(player.name, player_team_id)
        db_cursor.execute(player_count, (player.name, player_team_id))
        if db_cursor.fetchone()[0] == 0:
            db_cursor.execute(insert_player, (player.name, player_team_id))
            database.commit()

        db_cursor.execute(player_id, (player.name, player_team_id))
        year_players[player.name] = db_cursor.fetchone()[0]

    for tournament in tournaments:
        db_cursor.execute(tournament_count, (tournament.league, tournament.year, tournament.split))
        if db_cursor.fetchone()[0] == 0:
            db_cursor.execute(insert_tournament, (tournament.league, tournament.year, tournament.split))
            database.commit()

        db_cursor.execute(tournament_id, (tournament.league, tournament.year, tournament.split))
        current_tournament_id = db_cursor.fetchone()[0]
        
        for match in tournament.matches:
            # print(match.teamOne, match.teamTwo, match.date, match.playoffs, match.patch)
            db_cursor.execute(team_id, (match.teamOne.name, match.teamOne.year.item()))
            year_teams[match.teamOne.name] = db_cursor.fetchone()[0]
            db_cursor.execute(team_id, (match.teamTwo.name, match.teamTwo.year.item()))
            year_teams[match.teamTwo.name] = db_cursor.fetchone()[0]

            # print((current_tournament_id, match.date, year_teams[match.teamOne.name], year_teams[match.teamTwo.name], match.playoffs, match.patch))
            db_cursor.execute(match_count, (current_tournament_id, match.date, year_teams[match.teamOne.name], year_teams[match.teamTwo.name], match.playoffs, match.patch))
            if db_cursor.fetchone()[0] == 0:
                db_cursor.execute(insert_match, (current_tournament_id, match.date, year_teams[match.teamOne.name], year_teams[match.teamTwo.name], match.playoffs, match.patch))
                database.commit()

            db_cursor.execute(match_id, (current_tournament_id, match.date, year_teams[match.teamOne.name], year_teams[match.teamTwo.name], 
                                            match.playoffs, match.patch))
            current_match_id = db_cursor.fetchone()[0]

            for game in match.games:
                # print(current_match_id, game.number.item(), year_teams[game.blueTeam.name], year_teams[game.redTeam.name], game.blueWin.item(), game.duration.item())
                if math.isnan(game.number.item()):
                    continue
                db_cursor.execute(game_count, (current_match_id, game.number.item(), year_teams[game.blueTeam.name], year_teams[game.redTeam.name], game.blueWin.item(), game.duration.item()))
                if db_cursor.fetchone()[0] == 0:
                    db_cursor.execute(insert_game, (current_match_id, game.number.item(), year_teams[game.blueTeam.name], year_teams[game.redTeam.name], game.blueWin.item(), game.duration.item()))
                    database.commit()

                db_cursor.execute(game_id, (current_match_id, game.number.item(), year_teams[game.blueTeam.name], year_teams[game.redTeam.name], game.blueWin.item(), game.duration.item()))
                current_game_id = db_cursor.fetchone()[0]

                db_cursor.execute(objective_count, (current_game_id, 'Blue', game.blueObjectives.firstBlood, game.blueObjectives.firstTower, game.blueObjectives.towers, game.blueObjectives.plates, game.blueObjectives.voidGrubs, game.blueObjectives.riftHeralds, game.blueObjectives.baronNashtors, game.blueObjectives.infernalDragons, game.blueObjectives.mountainDragons, game.blueObjectives.cloudDragons, game.blueObjectives.oceanDragons, game.blueObjectives.hextechDragons, game.blueObjectives.chemtechDragons, game.blueObjectives.elderDragons, game.blueObjectives.featsOfStrength, game.blueObjectives.ruinousAtakhan, game.blueObjectives.voraciousAtakan))
                if db_cursor.fetchone()[0] == 0:
                    db_cursor.execute(insert_objective, (current_game_id, 'Blue', game.blueObjectives.firstBlood, game.blueObjectives.firstTower, game.blueObjectives.towers, game.blueObjectives.plates, game.blueObjectives.voidGrubs, game.blueObjectives.riftHeralds, game.blueObjectives.baronNashtors, game.blueObjectives.infernalDragons, game.blueObjectives.mountainDragons, game.blueObjectives.cloudDragons, game.blueObjectives.oceanDragons, game.blueObjectives.hextechDragons, game.blueObjectives.chemtechDragons, game.blueObjectives.elderDragons, game.blueObjectives.featsOfStrength, game.blueObjectives.ruinousAtakhan, game.blueObjectives.voraciousAtakan))
                    database.commit()

                db_cursor.execute(objective_count, (current_game_id, 'Red', game.redObjectives.firstBlood, game.redObjectives.firstTower, game.redObjectives.towers, game.redObjectives.plates, game.redObjectives.voidGrubs, game.redObjectives.riftHeralds, game.redObjectives.baronNashtors, game.redObjectives.infernalDragons, game.redObjectives.mountainDragons, game.redObjectives.cloudDragons, game.redObjectives.oceanDragons, game.redObjectives.hextechDragons, game.redObjectives.chemtechDragons, game.redObjectives.elderDragons, game.redObjectives.featsOfStrength, game.redObjectives.ruinousAtakhan, game.redObjectives.voraciousAtakan))
                if db_cursor.fetchone()[0] == 0:
                    db_cursor.execute(insert_objective, (current_game_id, 'Red', game.redObjectives.firstBlood, game.redObjectives.firstTower, game.redObjectives.towers, game.redObjectives.plates, game.redObjectives.voidGrubs, game.redObjectives.riftHeralds, game.redObjectives.baronNashtors, game.redObjectives.infernalDragons, game.redObjectives.mountainDragons, game.redObjectives.cloudDragons, game.redObjectives.oceanDragons, game.redObjectives.hextechDragons, game.redObjectives.chemtechDragons, game.redObjectives.elderDragons, game.redObjectives.featsOfStrength, game.redObjectives.ruinousAtakhan, game.redObjectives.voraciousAtakan))
                    database.commit()

                print(game.bluePickBan.bans)
                print(game.bluePickBan.picks)
                print(game.redPickBan.bans)
                print(game.redPickBan.picks)
                for i in range(1, 6):
                    db_cursor.execute(pick_ban_count, (current_game_id, 'Blue', 'Ban', i))
                    if db_cursor.fetchone()[0] == 0:
                        db_cursor.execute(insert_pick_ban, (current_game_id, 'Blue', 'Ban', i, game.bluePickBan.bans[i-1]))
                        database.commit()

                    db_cursor.execute(pick_ban_count, (current_game_id, 'Red', 'Ban', i))
                    if db_cursor.fetchone()[0] == 0:
                        db_cursor.execute(insert_pick_ban, (current_game_id, 'Red', 'Ban', i, game.redPickBan.bans[i-1]))
                        database.commit()

                    db_cursor.execute(pick_ban_count, (current_game_id, 'Blue', 'Pick', i))
                    if db_cursor.fetchone()[0] == 0:
                        db_cursor.execute(insert_pick_ban, (current_game_id, 'Blue', 'Pick', i, game.bluePickBan.picks[i-1]))
                        database.commit()

                    db_cursor.execute(pick_ban_count, (current_game_id, 'Red', 'Pick', i))
                    if db_cursor.fetchone()[0] == 0:
                        db_cursor.execute(insert_pick_ban, (current_game_id, 'Red', 'Pick', i, game.redPickBan.picks[i-1]))
                        database.commit()

                # db_cursor.execute(pick_ban_count, (current_game_id, 'Blue'))
                # if db_cursor.fetchone()[0] == 0:
                #     print((current_game_id, 'Blue', game.bluePickBan.ban1, game.bluePickBan.ban2, game.bluePickBan.ban3, game.bluePickBan.ban4, game.bluePickBan.ban5, game.bluePickBan.pick1, game.bluePickBan.pick2, game.bluePickBan.pick3, game.bluePickBan.pick4, game.bluePickBan.pick5))
                #     db_cursor.execute(insert_pick_ban, (current_game_id, 'Blue', game.bluePickBan.ban1, game.bluePickBan.ban2, game.bluePickBan.ban3, game.bluePickBan.ban4, game.bluePickBan.ban5, game.bluePickBan.pick1, game.bluePickBan.pick2, game.bluePickBan.pick3, game.bluePickBan.pick4, game.bluePickBan.pick5))
                #     database.commit()

                # db_cursor.execute(pick_ban_count, (current_game_id, 'Red'))
                # if db_cursor.fetchone()[0] == 0:
                #     db_cursor.execute(insert_pick_ban, (current_game_id, 'Red', game.redPickBan.ban1, game.redPickBan.ban2, game.redPickBan.ban3, game.redPickBan.ban4, game.redPickBan.ban5, game.redPickBan.pick1, game.redPickBan.pick2, game.redPickBan.pick3, game.redPickBan.pick4, game.redPickBan.pick5))
                #     database.commit()
                
                for player in game.bluePlayerPerformances:
                    # print((player.player.name, year_teams[player.player.team.name]))
                    db_cursor.execute(player_id, (player.player.name, year_teams[player.player.team.name]))
                    year_players[player.player.name] = db_cursor.fetchone()[0]

                    db_cursor.execute(player_performance_count, (current_game_id, year_players[player.player.name], player.role, player.champion))
                    if db_cursor.fetchone()[0] == 0:
                        db_cursor.execute(insert_player_performance, (current_game_id, year_players[player.player.name], player.role, player.champion, player.kills, player.deaths, player.assists, player.damageToChampions, player.wardsPlaced, player.wardsKilled, player.controlWardsBought, player.visionScore, player.totalGold, player.goldSpent, player.creepScore, player.killsAt15, player.deathsAt15, player.assistsAt15, player.goldAt15))
                        database.commit()

                for player in game.redPlayerPerformances:
                    db_cursor.execute(player_id, (player.player.name, year_teams[player.player.team.name]))
                    year_players[player.player.name] = db_cursor.fetchone()[0]

                    db_cursor.execute(player_performance_count, (current_game_id, year_players[player.player.name], player.role, player.champion))
                    if db_cursor.fetchone()[0] == 0:
                        # print(current_game_id, year_players[player.player.name], player.player.name)
                        db_cursor.execute(insert_player_performance, (current_game_id, year_players[player.player.name], player.role, player.champion, player.kills, player.deaths, player.assists, player.damageToChampions, player.wardsPlaced, player.wardsKilled, player.controlWardsBought, player.visionScore, player.totalGold, player.goldSpent, player.creepScore, player.killsAt15, player.deathsAt15, player.assistsAt15, player.goldAt15))
                        database.commit()
# Out:
# C:\Users\ktann\AppData\Local\Temp\ipykernel_205552\3123184168.py:2: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(csv_file)
# LFL2 2025 - Winter
# LCKC 2025 - Kickoff
# LVP SL 2025 - Winter
# LCK 2025 - Cup
# NLC 2025 - Winter
# LCP 2025 - Split 1
# LEC 2025 - Winter
# HLL 2025 - Winter
# PRM 2025 - Winter
# LFL 2025 - Flash In
# LIT 2025 - Winter
# TCL 2025 - Winter
# HW 2025 - N/A
# LJL 2025 - N/A
# LTA S 2025 - Split 1
# LTA N 2025 - Split 1
# RL 2025 - Winter
# LJL 2025 - Forge
# NEXO 2025 - Split 2
# CD 2025 - N/A
# EBL 2025 - Winter
# PCS 2025 - Split 1
# ROL 2025 - Winter
# LPLOL 2025 - Winter
# AL 2025 - Winter
# LTA 2025 - N/A
# VCS 2025 - Spring
# FST 2025 - N/A
# PCS 2025 - N/A
# EM 2025 - Winter
# CD 2025 - Split 1
# LRS 2025 - Split 1
# LRN 2025 - Split 1
# PRM 2025 - Spring
# ROL 2025 - Spring
# NACL 2025 - Split 1
# TCL 2025 - Spring
# LAS 2025 - Champ 1
# LEC 2025 - Spring
# LCKC 2025 - Rounds 1-2
# HLL 2025 - Spring
# LCK 2025 - Rounds 1-2
# HC 2025 - Spring
# NLC 2025 - Spring
# LIT 2025 - Spring
# LJL 2025 - Storm
# PRMP 2025 - N/A
# LTA S 2025 - Split 2
# LTA N 2025 - Split 2
# PCS 2025 - Split 2
# HM 2025 - Spring
# RL 2025 - Spring
# LVP SL 2025 - Spring
# LFL 2025 - Spring
# AL 2025 - Spring
# EBL 2025 - Spring
# LFL2 2025 - Spring
# LPLOL 2025 - Spring
# LCP 2025 - Split 2
# VCS 2025 - Summer
# NEXO 2025 - Split 3
# LJL 2025 - Ignite
# ['Vi', 'Skarner', 'Corki', "K'Sante", 'Sylas']
# ['Maokai', 'Jinx', 'Leona', 'Hwei', 'Gnar']
# ['Yone', 'Viktor', 'Aurora', 'Nocturne', 'Jarvan IV']
# ['Varus', 'Ivern', 'Braum', 'Renekton', 'Orianna']
# ['Vi', 'Skarner', 'Corki', "K'Sante", 'Sylas']
# ['Maokai', 'Jinx', 'Leona', 'Hwei', 'Gnar']
# ['Yone', 'Viktor', 'Aurora', 'Nocturne', 'Jarvan IV']
# ['Varus', 'Ivern', 'Braum', 'Renekton', 'Orianna']
# ['Kalista', 'Aurora', 'Skarner', 'Akali', 'Ziggs']
# ['Varus', "K'Sante", 'Ivern', 'Azir', 'Rell']
# ['Fiora', 'Nocturne', 'Ashe', 'Leona', 'Yone']
# ['Corki', 'Sejuani', 'Renekton', 'Orianna', 'Nautilus']
# ['Kalista', 'Aurora', 'Skarner', 'Akali', 'Ziggs']
# ['Varus', "K'Sante", 'Ivern', 'Azir', 'Rell']
# ['Fiora', 'Nocturne', 'Ashe', 'Leona', 'Yone']
# ['Corki', 'Sejuani', 'Renekton', 'Orianna', 'Nautilus']
# ['Irelia', 'Leona', 'Ivern', 'Sylas', 'Olaf']
# ['Corki', 'Skarner', 'Alistar', 'Aurora', 'Aatrox']
# ['Viktor', 'Caitlyn', "K'Sante", 'Zed', 'Hwei']
# ['Varus', 'Rell', 'Kayn', 'Taliyah', 'Gwen']
# ['Irelia', 'Leona', 'Ivern', 'Sylas', 'Olaf']
# ['Corki', 'Skarner', 'Alistar', 'Aurora', 'Aatrox']
# ['Viktor', 'Caitlyn', "K'Sante", 'Zed', 'Hwei']
# ['Varus', 'Rell', 'Kayn', 'Taliyah', 'Gwen']
# ['Kalista', 'Sejuani', 'Vi', 'Fiora', 'Ambessa']
# ['Viktor', 'Skarner', 'Ezreal', 'Nautilus', 'Jayce']
# ['Akali', 'Aurora', 'Maokai', 'Olaf', 'Renekton']
# ['Wukong', 'Varus', 'Ahri', 'Rakan', "K'Sante"]
# ['Kalista', 'Sejuani', 'Vi', 'Fiora', 'Ambessa']
# ['Viktor', 'Skarner', 'Ezreal', 'Nautilus', 'Jayce']
# ['Akali', 'Aurora', 'Maokai', 'Olaf', 'Renekton']
# ['Wukong', 'Varus', 'Ahri', 'Rakan', "K'Sante"]
# ['Zed', 'Aphelios', 'Maokai', 'Aatrox', "K'Sante"]
# ['Skarner', 'Ashe', 'Orianna', 'Ornn', 'Rakan']
# ['Viktor', 'Corki', 'Aurora', 'Rumble', 'Gnar']
# ['Wukong', 'Varus', 'LeBlanc', 'Renekton', 'Rell']
# ['Zed', 'Aphelios', 'Maokai', 'Aatrox', "K'Sante"]
# ['Skarner', 'Ashe', 'Orianna', 'Ornn', 'Rakan']
# ['Viktor', 'Corki', 'Aurora', 'Rumble', 'Gnar']
# ['Wukong', 'Varus', 'LeBlanc', 'Renekton', 'Rell']
# ['Kalista', 'Skarner', 'Vi', 'Renekton', 'Braum']
# ['Varus', 'Maokai', 'Orianna', 'Rell', 'Xin Zhao']
# ['Yone', 'Aurora', 'Viktor', 'Nocturne', 'Poppy']
# ['Ashe', 'Sejuani', 'Hwei', "K'Sante", 'Milio']
# ['Kalista', 'Skarner', 'Vi', 'Renekton', 'Braum']
# ['Varus', 'Maokai', 'Orianna', 'Rell', 'Xin Zhao']
# ['Yone', 'Aurora', 'Viktor', 'Nocturne', 'Poppy']
# ['Ashe', 'Sejuani', 'Hwei', "K'Sante", 'Milio']
# ['Kalista', 'Skarner', 'Varus', 'Ezreal', 'Rakan']
# ['Aurora', 'Corki', 'Garen', 'Vi', 'Rell']
# ['Fiora', 'Ivern', 'Viktor', 'Maokai', 'Nocturne']
# ['Wukong', "K'Sante", 'Orianna', 'Zeri', 'Alistar']
# ['Kalista', 'Skarner', 'Varus', 'Ezreal', 'Rakan']
# ['Aurora', 'Corki', 'Garen', 'Vi', 'Rell']
# ['Fiora', 'Ivern', 'Viktor', 'Maokai', 'Nocturne']
# ['Wukong', "K'Sante", 'Orianna', 'Zeri', 'Alistar']
# ['Viktor', 'Wukong', 'Olaf', 'Poppy', 'Gwen']
# ['Corki', "K'Sante", 'Rell', 'Karthus', 'Sivir']
# ['Kayn', 'Aurora', 'Ivern', 'Hwei', 'Taliyah']
# ['Varus', 'Vi', 'Ahri', 'Ambessa', 'Alistar']
# ['Viktor', 'Wukong', 'Olaf', 'Poppy', 'Gwen']
# ['Corki', "K'Sante", 'Rell', 'Karthus', 'Sivir']
# ['Kayn', 'Aurora', 'Ivern', 'Hwei', 'Taliyah']
# ['Varus', 'Vi', 'Ahri', 'Ambessa', 'Alistar']
# ['Not Found', 'Jayce', 'Orianna', "K'Sante", 'Alistar']
# ['Corki', 'Maokai', 'Varus', 'Nidalee', 'Rell']
# ['Kalista', 'Ivern', 'Skarner', 'Garen', 'Ambessa']
# ['Wukong', 'Aurora', 'Ashe', 'Jax', 'Leona']
# ['Not Found', 'Jayce', 'Orianna', "K'Sante", 'Alistar']
# ['Corki', 'Maokai', 'Varus', 'Nidalee', 'Rell']
# ['Kalista', 'Ivern', 'Skarner', 'Garen', 'Ambessa']
# ['Wukong', 'Aurora', 'Ashe', 'Jax', 'Leona']
# ['Kayn', 'Aurora', 'Varus', 'Ambessa', "K'Sante"]
# ['Corki', 'Skarner', 'Nautilus', 'Renekton', 'Annie']
# ['Viktor', 'Fiora', 'Ivern', 'Garen', 'Rumble']
# ['Rell', "Kog'Maw", 'Karthus', 'Jax', 'Smolder']
# ['Kayn', 'Aurora', 'Varus', 'Ambessa', "K'Sante"]
# ['Corki', 'Skarner', 'Nautilus', 'Renekton', 'Annie']
# ['Viktor', 'Fiora', 'Ivern', 'Garen', 'Rumble']
# ['Rell', "Kog'Maw", 'Karthus', 'Jax', 'Smolder']
# ['Yone', 'Viktor', 'Wukong', 'Nocturne', 'Rell']
# ['Corki', 'Xin Zhao', 'Hwei', "K'Sante", 'Nautilus']
# ['Skarner', 'Aurora', 'Ambessa', 'Alistar', 'Renekton']
# ['Varus', 'Maokai', 'Orianna', 'Viego', 'Braum']
# ['Yone', 'Viktor', 'Wukong', 'Nocturne', 'Rell']
# ['Corki', 'Xin Zhao', 'Hwei', "K'Sante", 'Nautilus']
# ['Skarner', 'Aurora', 'Ambessa', 'Alistar', 'Renekton']
# ['Varus', 'Maokai', 'Orianna', 'Viego', 'Braum']
# ['Wukong', 'Vi', "K'Sante", 'Xin Zhao', 'Viego']
# ['Skarner', 'Varus', 'Rell', 'Hwei', 'Renekton']
# ['Viktor', 'Corki', 'Jayce', 'Orianna', 'Aurora']
# ['Galio', 'Nautilus', 'Senna', 'Diana', 'Gnar']
# ['Wukong', 'Vi', "K'Sante", 'Xin Zhao', 'Viego']
# ['Skarner', 'Varus', 'Rell', 'Hwei', 'Renekton']
# ['Viktor', 'Corki', 'Jayce', 'Orianna', 'Aurora']
# ['Galio', 'Nautilus', 'Senna', 'Diana', 'Gnar']
# ['Kayn', 'Rell', 'Smolder', 'Karthus', 'Wukong']
# ['Varus', 'Skarner', "K'Sante", 'Orianna', 'Rakan']
# ['Kalista', 'Ivern', 'Corki', 'Aurora', 'Viktor']
# ['Ezreal', 'Leona', 'Olaf', 'Lillia', 'Akali']
# ['Kayn', 'Rell', 'Smolder', 'Karthus', 'Wukong']
# ['Varus', 'Skarner', "K'Sante", 'Orianna', 'Rakan']
# ['Kalista', 'Ivern', 'Corki', 'Aurora', 'Viktor']
# ['Ezreal', 'Leona', 'Olaf', 'Lillia', 'Akali']
# ['Fiora', "K'Sante", 'Kalista', 'Alistar', 'Ezreal']
# ['Ashe', 'Rumble', 'Rell', 'Jarvan IV', 'Akali']
# ['Skarner', 'Varus', 'Corki', 'Viktor', 'Galio']
# ['Orianna', 'Nocturne', 'Ornn', 'Miss Fortune', 'Poppy']
# ['Fiora', "K'Sante", 'Kalista', 'Alistar', 'Ezreal']
# ['Ashe', 'Rumble', 'Rell', 'Jarvan IV', 'Akali']
# ['Skarner', 'Varus', 'Corki', 'Viktor', 'Galio']
# ['Orianna', 'Nocturne', 'Ornn', 'Miss Fortune', 'Poppy']
# ['Ivern', 'Maokai', 'Corki', 'Poppy', 'Renata Glasc']
# ['Varus', 'Lee Sin', "K'Sante", 'Ahri', 'Rell']
# ['Skarner', 'Vi', 'Aurora', 'Akali', 'Orianna']
# ['Kalista', 'Wukong', 'Viktor', 'Renekton', 'Alistar']
# ['Ivern', 'Maokai', 'Corki', 'Poppy', 'Renata Glasc']
# ['Varus', 'Lee Sin', "K'Sante", 'Ahri', 'Rell']
# ['Skarner', 'Vi', 'Aurora', 'Akali', 'Orianna']
# ['Kalista', 'Wukong', 'Viktor', 'Renekton', 'Alistar']
# ['Wukong', 'Viktor', 'Corki', 'Ahri', 'Akali']
# ['Aurora', 'Maokai', 'Aphelios', 'Alistar', 'Sylas']
# ["K'Sante", 'Hwei', 'Skarner', 'Ambessa', 'Aatrox']
# ['Jayce', 'Sejuani', 'Varus', 'Rell', 'Galio']
# ['Wukong', 'Viktor', 'Corki', 'Ahri', 'Akali']
# ['Aurora', 'Maokai', 'Aphelios', 'Alistar', 'Sylas']
# ["K'Sante", 'Hwei', 'Skarner', 'Ambessa', 'Aatrox']
# ['Jayce', 'Sejuani', 'Varus', 'Rell', 'Galio']
# ['Aurora', 'Karthus', 'Kayn', 'Galio', 'Irelia']
# ['Corki', 'Xin Zhao', 'Nautilus', 'Sylas', 'Rumble']
# ['Viktor', "K'Sante", 'Ivern', 'Jayce', 'Akali']
# ['Varus', 'Rell', 'Jax', 'Amumu', 'Ambessa']
# ['Aurora', 'Karthus', 'Kayn', 'Galio', 'Irelia']
# ['Corki', 'Xin Zhao', 'Nautilus', 'Sylas', 'Rumble']
# ['Viktor', "K'Sante", 'Ivern', 'Jayce', 'Akali']
# ['Varus', 'Rell', 'Jax', 'Amumu', 'Ambessa']
# ['Kalista', 'Vi', 'Varus', 'Nocturne', 'Maokai']
# ['Skarner', 'Poppy', 'Ezreal', 'Leona', 'Taliyah']
# ['Aurora', "K'Sante", 'Corki', 'Hwei', 'Yone']
# ['Ambessa', 'Rell', 'Orianna', "Kai'Sa", 'Olaf']
# ['Kalista', 'Vi', 'Varus', 'Nocturne', 'Maokai']
# ['Skarner', 'Poppy', 'Ezreal', 'Leona', 'Taliyah']
# ['Aurora', "K'Sante", 'Corki', 'Hwei', 'Yone']
# ['Ambessa', 'Rell', 'Orianna', "Kai'Sa", 'Olaf']
# ['Kalista', 'Corki', "K'Sante", 'Alistar', 'Nidalee']
# ['Skarner', 'Varus', 'Orianna', 'Rakan', 'Jax']
# ['Aurora', 'Vi', 'Viktor', 'Leona', 'Rell']
# ['Jayce', 'Maokai', 'Ezreal', 'Renekton', 'Morgana']
# ['Kalista', 'Corki', "K'Sante", 'Alistar', 'Nidalee']
# ['Skarner', 'Varus', 'Orianna', 'Rakan', 'Jax']
# ['Aurora', 'Vi', 'Viktor', 'Leona', 'Rell']
# ['Jayce', 'Maokai', 'Ezreal', 'Renekton', 'Morgana']
# ['Fiora', 'Ivern', 'Wukong', 'Garen', 'Rumble']
# ['Maokai', 'Aphelios', "K'Sante", 'Thresh', 'Hwei']
# ['Ambessa', 'Skarner', 'Aurora', 'Braum', 'Alistar']
# ['Varus', 'Sejuani', 'Rell', 'Darius', 'Akali']
# ['Fiora', 'Ivern', 'Wukong', 'Garen', 'Rumble']
# ['Maokai', 'Aphelios', "K'Sante", 'Thresh', 'Hwei']
# ['Ambessa', 'Skarner', 'Aurora', 'Braum', 'Alistar']
# ['Varus', 'Sejuani', 'Rell', 'Darius', 'Akali']
# ['Fiora', 'Aurora', 'Skarner', 'Yone', 'Jayce']
# ['Corki', 'Vi', "K'Sante", 'Leona', 'Akali']
# ['Kalista', 'Ambessa', 'Wukong', 'Ahri', 'Rakan']
# ['Varus', 'Maokai', 'Rumble', 'Rell', 'Galio']
# ['Fiora', 'Aurora', 'Skarner', 'Yone', 'Jayce']
# ['Corki', 'Vi', "K'Sante", 'Leona', 'Akali']
# ['Kalista', 'Ambessa', 'Wukong', 'Ahri', 'Rakan']
# ['Varus', 'Maokai', 'Rumble', 'Rell', 'Galio']
# ['Kalista', 'Olaf', "K'Sante", 'Renekton', 'Rell']
# ['Aurora', 'Maokai', 'Jhin', 'Nautilus', 'Ambessa']
# ['Corki', 'Skarner', 'Aphelios', 'Jax', 'Thresh']
# ['Jayce', 'Varus', 'Nidalee', 'Alistar', 'Kennen']
# ['Kalista', 'Olaf', "K'Sante", 'Renekton', 'Rell']
# ['Aurora', 'Maokai', 'Jhin', 'Nautilus', 'Ambessa']
# ['Corki', 'Skarner', 'Aphelios', 'Jax', 'Thresh']
# ['Jayce', 'Varus', 'Nidalee', 'Alistar', 'Kennen']
# ['Akali', 'Rell', 'Varus', 'Skarner', 'Smolder']
# ['Corki', 'Maokai', 'Rumble', "Kai'Sa", 'Rakan']
# ['Orianna', 'Ivern', 'Poppy', 'Jayce', 'Irelia']
# ["K'Sante", 'Leona', 'Ezreal', 'Yone', 'Karthus']
# ['Akali', 'Rell', 'Varus', 'Skarner', 'Smolder']
# ['Corki', 'Maokai', 'Rumble', "Kai'Sa", 'Rakan']
# ['Orianna', 'Ivern', 'Poppy', 'Jayce', 'Irelia']
# ["K'Sante", 'Leona', 'Ezreal', 'Yone', 'Karthus']
# ['Ivern', 'Ashe', 'Skarner', 'Maokai', 'Volibear']
# ['Corki', 'Amumu', 'Yone', 'Rell', 'Malphite']
# ["K'Sante", 'Varus', 'Aurora', 'Olaf', 'Jax']
# ['Jayce', 'Viktor', 'Caitlyn', 'Sejuani', 'Alistar']
# ['Ivern', 'Ashe', 'Skarner', 'Maokai', 'Volibear']
# ['Corki', 'Amumu', 'Yone', 'Rell', 'Malphite']
# ["K'Sante", 'Varus', 'Aurora', 'Olaf', 'Jax']
# ['Jayce', 'Viktor', 'Caitlyn', 'Sejuani', 'Alistar']
# ['Jayce', 'Aurora', 'Kalista', 'Nidalee', 'Zyra']
# ['Maokai', 'Ezreal', 'Viktor', 'Leona', 'Renekton']
# ['Ambessa', 'Skarner', 'Olaf', 'Gnar', 'Jax']
# ['Corki', "K'Sante", "Kai'Sa", 'Rell', 'Lillia']
# ['Jayce', 'Aurora', 'Kalista', 'Nidalee', 'Zyra']
# ['Maokai', 'Ezreal', 'Viktor', 'Leona', 'Renekton']
# ['Ambessa', 'Skarner', 'Olaf', 'Gnar', 'Jax']
# ['Corki', "K'Sante", "Kai'Sa", 'Rell', 'Lillia']
# ['Aphelios', 'Ivern', 'Ambessa', 'Alistar', 'Nautilus']
# ['Varus', 'Rell', 'Jayce', 'Amumu', 'Yone']
# ['Skarner', "K'Sante", 'Wukong', 'Vi', 'Zyra']
# ['Maokai', 'Jhin', 'Aurora', 'Leona', 'Aatrox']
# ['Aphelios', 'Ivern', 'Ambessa', 'Alistar', 'Nautilus']
# ['Varus', 'Rell', 'Jayce', 'Amumu', 'Yone']
# ['Skarner', "K'Sante", 'Wukong', 'Vi', 'Zyra']
# ['Maokai', 'Jhin', 'Aurora', 'Leona', 'Aatrox']
# ['Karthus', 'Leona', 'Varus', 'Lillia', 'Amumu']
# ['Rell', 'Zyra', 'Corki', "K'Sante", "Kai'Sa"]
# ['Orianna', 'Skarner', 'Ivern', 'Malphite', 'Irelia']
# ['Jayce', 'Nautilus', 'Smolder', 'Nunu & Willump', 'Taliyah']
# ['Karthus', 'Leona', 'Varus', 'Lillia', 'Amumu']
# ['Rell', 'Zyra', 'Corki', "K'Sante", "Kai'Sa"]
# ['Orianna', 'Skarner', 'Ivern', 'Malphite', 'Irelia']
# ['Jayce', 'Nautilus', 'Smolder', 'Nunu & Willump', 'Taliyah']
# ['Fiora', 'Sejuani', 'Maokai', 'Leona', 'Xayah']
# ['Skarner', 'Galio', 'Rell', 'Azir', 'Ezreal']
# ['Varus', "K'Sante", 'Kalista', 'Ashe', 'Orianna']
# ['Rumble', 'Corki', 'Ivern', 'Braum', "Kai'Sa"]
# ['Fiora', 'Sejuani', 'Maokai', 'Leona', 'Xayah']
# ['Skarner', 'Galio', 'Rell', 'Azir', 'Ezreal']
# ['Varus', "K'Sante", 'Kalista', 'Ashe', 'Orianna']
# ['Rumble', 'Corki', 'Ivern', 'Braum', "Kai'Sa"]
# ['Kalista', 'Jayce', "K'Sante", 'Ezreal', 'Ornn']
# ['Maokai', 'Rumble', 'Varus', 'Smolder', 'Nautilus']
# ['Fiora', 'Skarner', 'Aurora', 'Braum', 'Rell']
# ['Corki', 'Ivern', 'Leona', 'Galio', 'Hwei']
# ['Kalista', 'Jayce', "K'Sante", 'Ezreal', 'Ornn']
# ['Maokai', 'Rumble', 'Varus', 'Smolder', 'Nautilus']
# ['Fiora', 'Skarner', 'Aurora', 'Braum', 'Rell']
# ['Corki', 'Ivern', 'Leona', 'Galio', 'Hwei']
# ['Kalista', 'Ambessa', 'Wukong', "K'Sante", 'Malphite']
# ['Varus', 'Jayce', 'Leona', 'Xin Zhao', 'Syndra']
# ['Aurora', 'Yone', 'Amumu', 'Zyra', 'Maokai']
# ['Rell', 'Corki', 'Skarner', 'Gragas', "Kai'Sa"]
# ['Kalista', 'Ambessa', 'Wukong', "K'Sante", 'Malphite']
# ['Varus', 'Jayce', 'Leona', 'Xin Zhao', 'Syndra']
# ['Aurora', 'Yone', 'Amumu', 'Zyra', 'Maokai']
# ['Rell', 'Corki', 'Skarner', 'Gragas', "Kai'Sa"]
# ['Karthus', 'Irelia', 'Olaf', 'Ezreal', 'Varus']
# ['Jayce', 'Alistar', 'Maokai', 'Smolder', 'Viktor']
# ["K'Sante", 'Aphelios', 'Ivern', "Kai'Sa", 'Sivir']
# ['Hwei', 'Rell', 'Kayn', 'Ambessa', "Kog'Maw"]
# ['Karthus', 'Irelia', 'Olaf', 'Ezreal', 'Varus']
# ['Jayce', 'Alistar', 'Maokai', 'Smolder', 'Viktor']
# ["K'Sante", 'Aphelios', 'Ivern', "Kai'Sa", 'Sivir']
# ['Hwei', 'Rell', 'Kayn', 'Ambessa', "Kog'Maw"]
# ['Yone', 'Orianna', 'Maokai', 'Wukong', 'Jarvan IV']
# ['Varus', 'Rell', 'Ambessa', 'Nocturne', 'Hwei']
# ['Skarner', 'Ivern', 'Jayce', 'Sejuani', 'Vi']
# ['Corki', "K'Sante", 'Leona', 'Zyra', 'Ezreal']
# ['Yone', 'Orianna', 'Maokai', 'Wukong', 'Jarvan IV']
# ['Varus', 'Rell', 'Ambessa', 'Nocturne', 'Hwei']
# ['Skarner', 'Ivern', 'Jayce', 'Sejuani', 'Vi']
# ['Corki', "K'Sante", 'Leona', 'Zyra', 'Ezreal']
# ['Akali', 'Leona', 'Nautilus', 'Skarner', 'Amumu']
# ['Rell', 'Maokai', 'Ezreal', 'Rumble', 'Smolder']
# ['Varus', 'Jayce', 'Ivern', 'Orianna', 'Syndra']
# ["K'Sante", 'Taliyah', 'Janna', "Kog'Maw", 'Kindred']
# ['Akali', 'Leona', 'Nautilus', 'Skarner', 'Amumu']
# ['Rell', 'Maokai', 'Ezreal', 'Rumble', 'Smolder']
# ['Varus', 'Jayce', 'Ivern', 'Orianna', 'Syndra']
# ["K'Sante", 'Taliyah', 'Janna', "Kog'Maw", 'Kindred']
# ['Fiora', 'Ivern', 'Maokai', 'Leona', 'Poppy']
# ['Jayce', 'Varus', 'Rell', 'Yasuo', 'Diana']
# ['Kalista', 'Skarner', "K'Sante", 'Yone', 'Amumu']
# ['Corki', 'Zyra', 'Ezreal', 'Braum', 'Ornn']
# ['Fiora', 'Ivern', 'Maokai', 'Leona', 'Poppy']
# ['Jayce', 'Varus', 'Rell', 'Yasuo', 'Diana']
# ['Kalista', 'Skarner', "K'Sante", 'Yone', 'Amumu']
# ['Corki', 'Zyra', 'Ezreal', 'Braum', 'Ornn']
# ['Kalista', 'Jayce', 'Sejuani', 'Vi', 'Braum']
# ['Corki', "Kai'Sa", 'Maokai', 'Rakan', 'Poppy']
# ['Aurora', 'Skarner', 'Rumble', 'Gnar', 'Ambessa']
# ["K'Sante", 'Ezreal', 'Hwei', 'Rell', 'Zyra']
# ['Kalista', 'Jayce', 'Sejuani', 'Vi', 'Braum']
# ['Corki', "Kai'Sa", 'Maokai', 'Rakan', 'Poppy']
# ['Aurora', 'Skarner', 'Rumble', 'Gnar', 'Ambessa']
# ["K'Sante", 'Ezreal', 'Hwei', 'Rell', 'Zyra']
# ['Aphelios', 'Maokai', 'Smolder', 'Aurora', 'Jarvan IV']
# ['Corki', 'Zyra', 'Leona', "K'Sante", 'Ashe']
# ['Skarner', 'Ivern', 'Braum', 'Ornn', 'Ambessa']
# ['Jayce', 'Varus', 'Rell', 'Xin Zhao', 'Hwei']
# ['Aphelios', 'Maokai', 'Smolder', 'Aurora', 'Jarvan IV']
# ['Corki', 'Zyra', 'Leona', "K'Sante", 'Ashe']
# ['Skarner', 'Ivern', 'Braum', 'Ornn', 'Ambessa']
# ['Jayce', 'Varus', 'Rell', 'Xin Zhao', 'Hwei']
# ['Kalista', 'Ivern', 'Skarner', 'Xin Zhao', 'Poppy']
# ["K'Sante", 'Varus', 'Rakan', 'Pantheon', 'Ahri']
# ['Aurora', 'Yone', 'Amumu', 'Akali', 'Vi']
# ['Maokai', 'Corki', 'Viktor', 'Garen', 'Rell']
# ['Kalista', 'Ivern', 'Skarner', 'Xin Zhao', 'Poppy']
# ["K'Sante", 'Varus', 'Rakan', 'Pantheon', 'Ahri']
# ['Aurora', 'Yone', 'Amumu', 'Akali', 'Vi']
# ['Maokai', 'Corki', 'Viktor', 'Garen', 'Rell']
# ['Kalista', 'Corki', 'Yone', 'Smolder', 'Rell']
# ['Ivern', 'Caitlyn', 'Renekton', 'Alistar', 'Sylas']
# ['Skarner', 'Jayce', 'Maokai', 'Hwei', 'Braum']
# ["K'Sante", 'Varus', 'Amumu', 'Leona', 'Taliyah']
# ['Kalista', 'Corki', 'Yone', 'Smolder', 'Rell']
# ['Ivern', 'Caitlyn', 'Renekton', 'Alistar', 'Sylas']
# ['Skarner', 'Jayce', 'Maokai', 'Hwei', 'Braum']
# ["K'Sante", 'Varus', 'Amumu', 'Leona', 'Taliyah']
# ['Varus', 'Ambessa', 'Orianna', 'Rakan', 'Nautilus']
# ['Aurora', 'Leona', 'Zeri', 'Nocturne', 'Gragas']
# ['Maokai', 'Corki', 'Skarner', 'Wukong', "K'Sante"]
# ["Kai'Sa", 'Jayce', 'Vi', 'Rell', 'Ahri']
# ['Varus', 'Ambessa', 'Orianna', 'Rakan', 'Nautilus']
# ['Aurora', 'Leona', 'Zeri', 'Nocturne', 'Gragas']
# ['Maokai', 'Corki', 'Skarner', 'Wukong', "K'Sante"]
# ["Kai'Sa", 'Jayce', 'Vi', 'Rell', 'Ahri']
# ['Kayn', 'Smolder', "K'Sante", 'Taliyah', 'Hwei']
# ['Corki', 'Maokai', 'Rumble', 'Jayce', 'Braum']
# ['Fiora', 'Ivern', 'Orianna', 'Ezreal', 'Poppy']
# ['Varus', 'Rell', 'Kindred', 'Irelia', 'Syndra']
# ['Kayn', 'Smolder', "K'Sante", 'Taliyah', 'Hwei']
# ['Corki', 'Maokai', 'Rumble', 'Jayce', 'Braum']
# ['Fiora', 'Ivern', 'Orianna', 'Ezreal', 'Poppy']
# ['Varus', 'Rell', 'Kindred', 'Irelia', 'Syndra']
# ['Corki', 'Maokai', 'Kalista', 'Volibear', 'Renekton']
# ['Ivern', 'Leona', 'Ambessa', 'Ezreal', 'Gwen']
# ['Karthus', 'Akali', 'Smolder', "Kog'Maw", "Kai'Sa"]
# ['Skarner', 'Rell', 'Aurora', 'Draven', 'Garen']
# ['Corki', 'Maokai', 'Kalista', 'Volibear', 'Renekton']
# ['Ivern', 'Leona', 'Ambessa', 'Ezreal', 'Gwen']
# ['Karthus', 'Akali', 'Smolder', "Kog'Maw", "Kai'Sa"]
# ['Skarner', 'Rell', 'Aurora', 'Draven', 'Garen']
# ["K'Sante", 'Ivern', 'Corki', 'Orianna', 'Ahri']
# ['Maokai', 'Galio', 'Varus', 'Braum', 'Smolder']
# ['Fiora', 'Mel', 'Skarner', 'Jayce', 'Yone']
# ['Rumble', 'Vi', 'Ezreal', 'Leona', 'Hwei']
# ["K'Sante", 'Ivern', 'Corki', 'Orianna', 'Ahri']
# ['Maokai', 'Galio', 'Varus', 'Braum', 'Smolder']
# ['Fiora', 'Mel', 'Skarner', 'Jayce', 'Yone']
# ['Rumble', 'Vi', 'Ezreal', 'Leona', 'Hwei']
# ['Maokai', 'Varus', 'Poppy', 'Braum', 'Tahm Kench']
# ['Jayce', 'Vi', 'Akali', 'Zeri', 'Nautilus']
# ['Skarner', 'Rumble', "K'Sante", 'Ezreal', 'Leona']
# ['Zyra', 'Yone', 'Corki', 'Rell', 'Malphite']
# ['Maokai', 'Varus', 'Poppy', 'Braum', 'Tahm Kench']
# ['Jayce', 'Vi', 'Akali', 'Zeri', 'Nautilus']
# ['Skarner', 'Rumble', "K'Sante", 'Ezreal', 'Leona']
# ['Zyra', 'Yone', 'Corki', 'Rell', 'Malphite']
# ['Ambessa', 'Varus', 'Maokai', 'Hwei', 'Orianna']
# ['Viktor', 'Kalista', 'Renata Glasc', 'Xin Zhao', 'Renekton']
# ['Skarner', 'Corki', 'Aurora', 'Vi', 'Sejuani']
# ['Ivern', 'Rell', "K'Sante", 'Xayah', 'Akali']
# ['Ambessa', 'Varus', 'Maokai', 'Hwei', 'Orianna']
# ['Viktor', 'Kalista', 'Renata Glasc', 'Xin Zhao', 'Renekton']
# ['Skarner', 'Corki', 'Aurora', 'Vi', 'Sejuani']
# ['Ivern', 'Rell', "K'Sante", 'Xayah', 'Akali']
# ['Kalista', 'Maokai', 'Varus', "K'Sante", 'Draven']
# ['Mel', 'Jayce', 'Vi', 'Leona', 'Miss Fortune']
# ['Skarner', 'Ivern', 'Corki', 'Rakan', 'Ezreal']
# ['Rell', 'Nidalee', 'Ambessa', "Kai'Sa", 'Aurora']
# ['Kalista', 'Maokai', 'Varus', "K'Sante", 'Draven']
# ['Mel', 'Jayce', 'Vi', 'Leona', 'Miss Fortune']
# ['Skarner', 'Ivern', 'Corki', 'Rakan', 'Ezreal']
# ['Rell', 'Nidalee', 'Ambessa', "Kai'Sa", 'Aurora']
# ['Karthus', "Kog'Maw", 'Ivern', 'Nautilus', 'Leona']
# ['Ezreal', 'Renekton', 'Nidalee', 'Jayce', 'Rakan']
# ['Zyra', 'Corki', 'Rell', 'Yone', 'Irelia']
# ['Ambessa', 'Varus', 'Kindred', 'Braum', 'Gragas']
# ['Karthus', "Kog'Maw", 'Ivern', 'Nautilus', 'Leona']
# ['Ezreal', 'Renekton', 'Nidalee', 'Jayce', 'Rakan']
# ['Zyra', 'Corki', 'Rell', 'Yone', 'Irelia']
# ['Ambessa', 'Varus', 'Kindred', 'Braum', 'Gragas']
# ['Ivern', 'Aphelios', "K'Sante", 'Vi', 'Xin Zhao']
# ['Maokai', 'Varus', 'Rell', 'Mel', 'Garen']
# ['Skarner', 'Fiora', 'Rumble', 'Renekton', 'Ornn']
# ['Aurora', 'Corki', 'Ambessa', 'Alistar', 'Aatrox']
# ['Ivern', 'Aphelios', "K'Sante", 'Vi', 'Xin Zhao']
# ['Maokai', 'Varus', 'Rell', 'Mel', 'Garen']
# ['Skarner', 'Fiora', 'Rumble', 'Renekton', 'Ornn']
# ['Aurora', 'Corki', 'Ambessa', 'Alistar', 'Aatrox']
# ['Yone', 'Ivern', 'Varus', 'Poppy', 'Renekton']
# ['Corki', 'Vi', "Kai'Sa", 'Aurora', 'Leona']
# ['Skarner', 'Nocturne', 'Kalista', 'Rell', 'Rumble']
# ['Zyra', 'Ezreal', 'Hwei', "K'Sante", 'Braum']
# ['Yone', 'Ivern', 'Varus', 'Poppy', 'Renekton']
# ['Corki', 'Vi', "Kai'Sa", 'Aurora', 'Leona']
# ['Skarner', 'Nocturne', 'Kalista', 'Rell', 'Rumble']
# ['Zyra', 'Ezreal', 'Hwei', "K'Sante", 'Braum']
# ['Kalista', 'Aurora', 'Corki', "K'Sante", 'Ahri']
# ['Maokai', "Kai'Sa", 'Jayce', 'Braum', 'Rumble']
# ['Skarner', 'Varus', 'Ivern', 'Alistar', 'Leona']
# ['Sejuani', 'Rell', 'Zeri', 'Viktor', 'Riven']
# ['Kalista', 'Aurora', 'Corki', "K'Sante", 'Ahri']
# ['Maokai', "Kai'Sa", 'Jayce', 'Braum', 'Rumble']
# ['Skarner', 'Varus', 'Ivern', 'Alistar', 'Leona']
# ['Sejuani', 'Rell', 'Zeri', 'Viktor', 'Riven']
# ['Kalista', 'Jayce', 'Maokai', "Kai'Sa", 'Alistar']
# ['Ezreal', 'Rell', 'Pantheon', 'Rumble', 'Yone']
# ['Aphelios', 'Skarner', 'Corki', 'Aurora', 'Ambessa']
# ["K'Sante", 'Mel', 'Vi', 'Nautilus', 'Jinx']
# ['Kalista', 'Jayce', 'Maokai', "Kai'Sa", 'Alistar']
# ['Ezreal', 'Rell', 'Pantheon', 'Rumble', 'Yone']
# ['Aphelios', 'Skarner', 'Corki', 'Aurora', 'Ambessa']
# ["K'Sante", 'Mel', 'Vi', 'Nautilus', 'Jinx']
# ['Orianna', 'Corki', 'Zyra', 'Braum', 'Rell']
# ['Ivern', 'Leona', 'Irelia', 'Gwen', 'Sivir']
# ['Akali', 'Ambessa', 'Jayce', 'Smolder', 'Ezreal']
# ['Rumble', 'Yone', 'Maokai', 'Varus', 'Rakan']
# ['Orianna', 'Corki', 'Zyra', 'Braum', 'Rell']
# ['Ivern', 'Leona', 'Irelia', 'Gwen', 'Sivir']
# ['Akali', 'Ambessa', 'Jayce', 'Smolder', 'Ezreal']
# ['Rumble', 'Yone', 'Maokai', 'Varus', 'Rakan']
# ['Yone', 'Jayce', 'Amumu', 'Aurora', 'Ahri']
# ['Corki', 'Maokai', 'Varus', 'Leona', 'Ambessa']
# ['Skarner', 'Ivern', 'Zyra', 'Gnar', 'Gwen']
# ['Pantheon', "K'Sante", 'Ezreal', 'Syndra', 'Karma']
# ['Yone', 'Jayce', 'Amumu', 'Aurora', 'Ahri']
# ['Corki', 'Maokai', 'Varus', 'Leona', 'Ambessa']
# ['Skarner', 'Ivern', 'Zyra', 'Gnar', 'Gwen']
# ['Pantheon', "K'Sante", 'Ezreal', 'Syndra', 'Karma']
# ['Jayce', 'Kalista', 'Maokai', 'Rell', 'Alistar']
# ['Vi', 'Ambessa', 'Leona', 'Jinx', 'Viktor']
# ['Corki', 'Aurora', 'Skarner', "Kai'Sa", 'Taliyah']
# ["K'Sante", 'Mel', 'Ezreal', 'Poppy', 'Xin Zhao']
# ['Jayce', 'Kalista', 'Maokai', 'Rell', 'Alistar']
# ['Vi', 'Ambessa', 'Leona', 'Jinx', 'Viktor']
# ['Corki', 'Aurora', 'Skarner', "Kai'Sa", 'Taliyah']
# ["K'Sante", 'Mel', 'Ezreal', 'Poppy', 'Xin Zhao']
# ['Poppy', 'Yone', 'Orianna', 'Renekton', 'Gnar']
# ['Varus', 'Vi', 'Ambessa', 'Rakan', 'Azir']
# ['Fiora', 'Maokai', 'Corki', 'Braum', 'Rell']
# ['Ivern', 'Kalista', 'Leona', 'Aurora', 'Camille']
# ['Poppy', 'Yone', 'Orianna', 'Renekton', 'Gnar']
# ['Varus', 'Vi', 'Ambessa', 'Rakan', 'Azir']
# ['Fiora', 'Maokai', 'Corki', 'Braum', 'Rell']
# ['Ivern', 'Kalista', 'Leona', 'Aurora', 'Camille']
# ['Smolder', 'Ezreal', 'Akali', 'Karthus', 'Amumu']
# ['Varus', 'Skarner', 'Jayce', 'Leona', 'Mel']
# ['Corki', 'Ivern', 'Orianna', 'Irelia', 'Rakan']
# ['Ambessa', 'Maokai', "Kog'Maw", 'Rell', 'Kayn']
# ['Smolder', 'Ezreal', 'Akali', 'Karthus', 'Amumu']
# ['Varus', 'Skarner', 'Jayce', 'Leona', 'Mel']
# ['Corki', 'Ivern', 'Orianna', 'Irelia', 'Rakan']
# ['Ambessa', 'Maokai', "Kog'Maw", 'Rell', 'Kayn']
# ['Jayce', 'Amumu', 'Corki', 'Alistar', 'Rakan']
# ['Ezreal', 'Rell', 'Rumble', 'Pantheon', 'Aurora']
# ['Skarner', 'Maokai', 'Aphelios', 'Poppy', 'Taliyah']
# ['Ambessa', "Kai'Sa", 'Vi', 'Leona', 'Irelia']
# ['Jayce', 'Amumu', 'Corki', 'Alistar', 'Rakan']
# ['Ezreal', 'Rell', 'Rumble', 'Pantheon', 'Aurora']
# ['Skarner', 'Maokai', 'Aphelios', 'Poppy', 'Taliyah']
# ['Ambessa', "Kai'Sa", 'Vi', 'Leona', 'Irelia']
# ['Fiora', 'Corki', 'Braum', 'Azir', 'Jayce']
# ['Varus', 'Karma', 'Xin Zhao', 'Akali', 'Leona']
# ['Ivern', 'Ambessa', 'Kayn', 'Taliyah', 'Irelia']
# ['Maokai', 'Ezreal', 'Nautilus', 'Rumble', 'Tristana']
# ['Fiora', 'Corki', 'Braum', 'Azir', 'Jayce']
# ['Varus', 'Karma', 'Xin Zhao', 'Akali', 'Leona']
# ['Ivern', 'Ambessa', 'Kayn', 'Taliyah', 'Irelia']
# ['Maokai', 'Ezreal', 'Nautilus', 'Rumble', 'Tristana']
# ["Kog'Maw", 'Ambessa', 'Taliyah', 'Olaf', 'Irelia']
# ['Corki', 'Zyra', 'Braum', 'Ashe', 'Sion']
# ['Ivern', 'Fiora', 'Orianna', 'Ornn', 'Malphite']
# ['Rell', 'Smolder', 'Karthus', 'Jayce', 'Sivir']
# ["Kog'Maw", 'Ambessa', 'Taliyah', 'Olaf', 'Irelia']
# ['Corki', 'Zyra', 'Braum', 'Ashe', 'Sion']
# ['Ivern', 'Fiora', 'Orianna', 'Ornn', 'Malphite']
# ['Rell', 'Smolder', 'Karthus', 'Jayce', 'Sivir']
# ['Yone', 'Ezreal', 'Varus', 'Aurora', 'Camille']
# ['Skarner', 'Jhin', 'Orianna', 'Bard', 'Ambessa']
# ['Jayce', 'Vi', 'Corki', 'Rell', 'Rakan']
# ['Ivern', 'Ashe', 'Braum', 'Azir', 'Renekton']
# ['Yone', 'Ezreal', 'Varus', 'Aurora', 'Camille']
# ['Skarner', 'Jhin', 'Orianna', 'Bard', 'Ambessa']
# ['Jayce', 'Vi', 'Corki', 'Rell', 'Rakan']
# ['Ivern', 'Ashe', 'Braum', 'Azir', 'Renekton']
# ['Jayce', 'Vi', 'Akali', 'Smolder', 'Irelia']
# ['Varus', 'Pantheon', 'Aurora', 'Rakan', 'Rumble']
# ['Maokai', 'Corki', 'Yone', 'Rell', 'Nautilus']
# ['Ezreal', 'Leona', 'Zyra', 'Tristana', "K'Sante"]
# ['Jayce', 'Vi', 'Akali', 'Smolder', 'Irelia']
# ['Varus', 'Pantheon', 'Aurora', 'Rakan', 'Rumble']
# ['Maokai', 'Corki', 'Yone', 'Rell', 'Nautilus']
# ['Ezreal', 'Leona', 'Zyra', 'Tristana', "K'Sante"]
# ['Jayce', 'Vi', 'Poppy', 'Ahri', 'Taliyah']
# ['Rell', 'Xin Zhao', 'Draven', 'Syndra', 'Sion']
# ['Maokai', 'Corki', 'Yone', 'LeBlanc', 'Hwei']
# ['Miss Fortune', 'Nautilus', 'Jarvan IV', 'Viktor', "Cho'Gath"]
# ['Jayce', 'Vi', 'Poppy', 'Ahri', 'Taliyah']
# ['Rell', 'Xin Zhao', 'Draven', 'Syndra', 'Sion']
# ['Maokai', 'Corki', 'Yone', 'LeBlanc', 'Hwei']
# ['Miss Fortune', 'Nautilus', 'Jarvan IV', 'Viktor', "Cho'Gath"]
# ['Yone', 'Kalista', 'Wukong', 'Poppy', 'Camille']
# ['Corki', 'Viego', 'Ahri', 'Blitzcrank', 'Ornn']
# ['Jayce', 'Vi', 'Smolder', 'Pyke', 'Jax']
# ['Maokai', 'Caitlyn', 'Taliyah', 'Alistar', 'Gwen']
# ['Yone', 'Kalista', 'Wukong', 'Poppy', 'Camille']
# ['Corki', 'Viego', 'Ahri', 'Blitzcrank', 'Ornn']
# ['Jayce', 'Vi', 'Smolder', 'Pyke', 'Jax']
# ['Maokai', 'Caitlyn', 'Taliyah', 'Alistar', 'Gwen']
# ['Jayce', 'Sylas', 'Vi', 'Pyke', 'Gnar']
# ['Hwei', 'Kindred', 'Poppy', 'Galio', 'Aphelios']
# ['Yone', 'Kalista', 'Sivir', 'Xayah', 'Smolder']
# ['Sejuani', 'Akali', "Kai'Sa", 'Elise', 'Gangplank']
# ['Jayce', 'Sylas', 'Vi', 'Pyke', 'Gnar']
# ['Hwei', 'Kindred', 'Poppy', 'Galio', 'Aphelios']
# ['Yone', 'Kalista', 'Sivir', 'Xayah', 'Smolder']
# ['Sejuani', 'Akali', "Kai'Sa", 'Elise', 'Gangplank']
# ['Orianna', 'Corki', 'Ezreal', 'Sivir', 'Jhin']
# ['Varus', 'Karma', 'Xin Zhao', 'Braum', 'Sylas']
# ['Akali', 'Ambessa', 'Ivern', 'Gwen', 'Irelia']
# ['Yone', 'Maokai', 'Rumble', 'Rell', "Kai'Sa"]
# ['Orianna', 'Corki', 'Ezreal', 'Sivir', 'Jhin']
# ['Varus', 'Karma', 'Xin Zhao', 'Braum', 'Sylas']
# ['Akali', 'Ambessa', 'Ivern', 'Gwen', 'Irelia']
# ['Yone', 'Maokai', 'Rumble', 'Rell', "Kai'Sa"]
# ['Ambessa', 'Akali', 'Jayce', 'Karthus', 'Lillia']
# ['Taliyah', 'Kalista', 'Nautilus', 'Pantheon', 'Sion']
# ['Ivern', 'Corki', 'Orianna', 'Tristana', 'Smolder']
# ['Ezreal', 'Leona', 'Garen', 'Zyra', "K'Sante"]
# ['Ambessa', 'Akali', 'Jayce', 'Karthus', 'Lillia']
# ['Taliyah', 'Kalista', 'Nautilus', 'Pantheon', 'Sion']
# ['Ivern', 'Corki', 'Orianna', 'Tristana', 'Smolder']
# ['Ezreal', 'Leona', 'Garen', 'Zyra', "K'Sante"]
# ['Akali', 'Kindred', 'Karthus', 'Not Found', 'Not Found']
# ['Aurora', 'Vi', 'Renekton', 'Aphelios', 'Thresh']
# ['Ivern', 'Corki', 'Orianna', 'Draven', 'Jinx']
# ['Ambessa', 'Lulu', 'Sivir', 'Ornn', 'Amumu']
# ['Akali', 'Kindred', 'Karthus', 'Not Found', 'Not Found']
# ['Aurora', 'Vi', 'Renekton', 'Aphelios', 'Thresh']
# ['Ivern', 'Corki', 'Orianna', 'Draven', 'Jinx']
# ['Ambessa', 'Lulu', 'Sivir', 'Ornn', 'Amumu']
# ['Orianna', 'Azir', 'Tristana', 'Rakan', 'Seraphine']
# ['Corki', 'Wukong', 'Gwen', 'Neeko', 'Jayce']
# ['Akali', 'Ivern', 'Smolder', 'Janna', 'Jhin']
# ['Miss Fortune', 'Hwei', 'Sejuani', 'Alistar', 'Camille']
# ['Orianna', 'Azir', 'Tristana', 'Rakan', 'Seraphine']
# ['Corki', 'Wukong', 'Gwen', 'Neeko', 'Jayce']
# ['Akali', 'Ivern', 'Smolder', 'Janna', 'Jhin']
# ['Miss Fortune', 'Hwei', 'Sejuani', 'Alistar', 'Camille']
# ['Orianna', 'Azir', 'Kindred', 'Malphite', 'Poppy']
# ['Senna', 'Aurelion Sol', 'Nilah', 'Jax', 'Jarvan IV']
# ['Akali', 'Ivern', 'Smolder', 'Nocturne', 'Irelia']
# ['Jinx', 'Viktor', 'Rakan', 'Gnar', 'Viego']
# ['Orianna', 'Azir', 'Kindred', 'Malphite', 'Poppy']
# ['Senna', 'Aurelion Sol', 'Nilah', 'Jax', 'Jarvan IV']
# ['Akali', 'Ivern', 'Smolder', 'Nocturne', 'Irelia']
# ['Jinx', 'Viktor', 'Rakan', 'Gnar', 'Viego']
# ['Taliyah', 'Ambessa', 'Smolder', 'Braum', 'Akali']
# ['Varus', 'Maokai', 'Jayce', "K'Sante", 'Leona']
# ['Ivern', 'Fiora', 'Corki', 'Blitzcrank', 'Rell']
# ['Ezreal', 'Karma', 'Xin Zhao', 'Sylas', 'Olaf']
# ['Viktor', 'Kalista', 'Varus', 'Ezreal', 'Poppy']
# ['Corki', "K'Sante", 'Maokai', 'Jhin', 'Leona']
# ['Skarner', 'Zyra', 'Ashe', 'Miss Fortune', 'Azir']
# ['Jayce', 'Sejuani', 'Taliyah', 'Caitlyn', 'Braum']
# ['Viktor', 'Kalista', 'Varus', 'Ezreal', 'Poppy']
# ['Corki', "K'Sante", 'Maokai', 'Jhin', 'Leona']
# ['Skarner', 'Zyra', 'Ashe', 'Miss Fortune', 'Azir']
# ['Jayce', 'Sejuani', 'Taliyah', 'Caitlyn', 'Braum']
# ['Ambessa', 'Poppy', 'Azir', 'Jax', 'Neeko']
# ['Viktor', 'Wukong', 'Ezreal', 'Rell', 'Renekton']
# ['Skarner', 'Kalista', 'Rumble', 'Karma', 'Alistar']
# ['Varus', 'Vi', 'Akali', 'Rakan', 'Gnar']
# ['Ambessa', 'Poppy', 'Azir', 'Jax', 'Neeko']
# ['Viktor', 'Wukong', 'Ezreal', 'Rell', 'Renekton']
# ['Skarner', 'Kalista', 'Rumble', 'Karma', 'Alistar']
# ['Varus', 'Vi', 'Akali', 'Rakan', 'Gnar']
# ['Kalista', 'Ashe', 'Aurora', 'Vi', 'Wukong']
# ['Corki', 'Maokai', 'Leona', 'Ivern', 'Tristana']
# ['Skarner', 'Ziggs', "Kog'Maw", 'Zyra', 'Akali']
# ['Viktor', "K'Sante", 'Varus', 'Viego', 'Rell']
# ['Kalista', 'Ashe', 'Aurora', 'Vi', 'Wukong']
# ['Corki', 'Maokai', 'Leona', 'Ivern', 'Tristana']
# ['Skarner', 'Ziggs', "Kog'Maw", 'Zyra', 'Akali']
# ['Viktor', "K'Sante", 'Varus', 'Viego', 'Rell']
# ['Kalista', 'Ashe', 'Ambessa', 'Ornn', 'Rakan']
# ['Rumble', 'Azir', 'Wukong', 'Miss Fortune', 'Alistar']
# ['Skarner', 'Ziggs', 'Sejuani', 'Xayah', 'Jhin']
# ['Aurora', 'Vi', "Kai'Sa", 'Camille', 'Nautilus']
# ['Kalista', 'Ashe', 'Ambessa', 'Ornn', 'Rakan']
# ['Rumble', 'Azir', 'Wukong', 'Miss Fortune', 'Alistar']
# ['Skarner', 'Ziggs', 'Sejuani', 'Xayah', 'Jhin']
# ['Aurora', 'Vi', "Kai'Sa", 'Camille', 'Nautilus']
# ["K'Sante", 'Rumble', 'Poppy', 'Ambessa', 'Maokai']
# ['Aurora', 'Ezreal', 'Jayce', 'Vi', 'Rakan']
# ['Skarner', 'Viktor', 'Nocturne', 'Xin Zhao', 'Wukong']
# ['Varus', 'Azir', 'Viego', 'Jax', 'Rell']
# ["K'Sante", 'Rumble', 'Poppy', 'Ambessa', 'Maokai']
# ['Aurora', 'Ezreal', 'Jayce', 'Vi', 'Rakan']
# ['Skarner', 'Viktor', 'Nocturne', 'Xin Zhao', 'Wukong']
# ['Varus', 'Azir', 'Viego', 'Jax', 'Rell']
# ['Skarner', 'Viktor', 'Ashe', 'Caitlyn', 'Xayah']
# ["K'Sante", 'Akali', 'Wukong', 'Smolder', 'Maokai']
# ['Zyra', 'Kalista', 'Corki', 'Miss Fortune', 'Jhin']
# ['Yone', 'Sejuani', 'Rumble', 'Poppy', "Kai'Sa"]
# ['Skarner', 'Viktor', 'Ashe', 'Caitlyn', 'Xayah']
# ["K'Sante", 'Akali', 'Wukong', 'Smolder', 'Maokai']
# ['Zyra', 'Kalista', 'Corki', 'Miss Fortune', 'Jhin']
# ['Yone', 'Sejuani', 'Rumble', 'Poppy', "Kai'Sa"]
# ['Skarner', 'Viktor', 'Renekton', 'Neeko', 'Pyke']
# ['Corki', 'Ashe', 'Lee Sin', 'Braum', 'Ornn']
# ['Zyra', 'Ambessa', 'Galio', 'Gnar', 'Renata Glasc']
# ['Kalista', 'Xin Zhao', 'Taliyah', 'Gragas', 'Taric']
# ['Skarner', 'Viktor', 'Renekton', 'Neeko', 'Pyke']
# ['Corki', 'Ashe', 'Lee Sin', 'Braum', 'Ornn']
# ['Zyra', 'Ambessa', 'Galio', 'Gnar', 'Renata Glasc']
# ['Kalista', 'Xin Zhao', 'Taliyah', 'Gragas', 'Taric']
# ['Nocturne', "K'Sante", 'Sejuani', 'Leona', 'Braum']
# ['Corki', 'Zyra', 'Varus', 'Nautilus', 'Gragas']
# ['Viktor', 'Skarner', 'Kalista', 'Renekton', 'Ambessa']
# ['Ashe', 'Azir', 'Viego', 'Ornn', 'Rell']
# ['Nocturne', "K'Sante", 'Sejuani', 'Leona', 'Braum']
# ['Corki', 'Zyra', 'Varus', 'Nautilus', 'Gragas']
# ['Viktor', 'Skarner', 'Kalista', 'Renekton', 'Ambessa']
# ['Ashe', 'Azir', 'Viego', 'Ornn', 'Rell']
# ['Poppy', 'Kindred', "K'Sante", 'Braum', 'Xin Zhao']
# ['Kalista', 'Vi', 'Aurora', 'Leona', 'Camille']
# ['Skarner', 'Viktor', 'Nocturne', 'Renekton', 'Pyke']
# ['Caitlyn', 'Neeko', 'Ambessa', 'Orianna', 'Wukong']
# ['Poppy', 'Kindred', "K'Sante", 'Braum', 'Xin Zhao']
# ['Kalista', 'Vi', 'Aurora', 'Leona', 'Camille']
# ['Skarner', 'Viktor', 'Nocturne', 'Renekton', 'Pyke']
# ['Caitlyn', 'Neeko', 'Ambessa', 'Orianna', 'Wukong']
# ['Poppy', 'Varus', 'Ashe', "Kai'Sa", 'Caitlyn']
# ['Skarner', 'Azir', 'Ambessa', 'Corki', 'Renata Glasc']
# ['Viktor', 'Zyra', 'Kalista', 'Xayah', 'Ezreal']
# ["K'Sante", 'Aurora', 'Nocturne', 'Rakan', 'Aphelios']
# ['Poppy', 'Varus', 'Ashe', "Kai'Sa", 'Caitlyn']
# ['Skarner', 'Azir', 'Ambessa', 'Corki', 'Renata Glasc']
# ['Viktor', 'Zyra', 'Kalista', 'Xayah', 'Ezreal']
# ["K'Sante", 'Aurora', 'Nocturne', 'Rakan', 'Aphelios']
# ['Yone', 'Viktor', 'Zyra', 'Ahri', 'LeBlanc']
# ['Ezreal', 'Jax', 'Sejuani', 'Akali', 'Leona']
# ['Kalista', 'Varus', 'Ashe', 'Karma', 'Orianna']
# ['Rumble', 'Vi', 'Jhin', 'Poppy', 'Galio']
# ['Yone', 'Viktor', 'Zyra', 'Ahri', 'LeBlanc']
# ['Ezreal', 'Jax', 'Sejuani', 'Akali', 'Leona']
# ['Kalista', 'Varus', 'Ashe', 'Karma', 'Orianna']
# ['Rumble', 'Vi', 'Jhin', 'Poppy', 'Galio']
# ["K'Sante", 'Poppy', 'Sejuani', 'Sylas', 'Renata Glasc']
# ['Vi', 'Ambessa', 'Taliyah', 'Corki', 'Nautilus']
# ['Skarner', 'Kalista', 'Viktor', 'Ashe', 'Ezreal']
# ['Rumble', 'Xin Zhao', 'Varus', 'Yone', 'Rell']
# ["K'Sante", 'Poppy', 'Sejuani', 'Sylas', 'Renata Glasc']
# ['Vi', 'Ambessa', 'Taliyah', 'Corki', 'Nautilus']
# ['Skarner', 'Kalista', 'Viktor', 'Ashe', 'Ezreal']
# ['Rumble', 'Xin Zhao', 'Varus', 'Yone', 'Rell']
# ['Poppy', 'Aurora', 'Viktor', 'Sylas', 'Azir']
# ['Varus', 'Vi', 'Rumble', 'Ahri', 'Rell']
# ['Skarner', 'Kalista', 'Zyra', 'Neeko', 'Orianna']
# ['Jayce', 'Sejuani', 'Ezreal', 'Corki', 'Braum']
# ['Poppy', 'Aurora', 'Viktor', 'Sylas', 'Azir']
# ['Varus', 'Vi', 'Rumble', 'Ahri', 'Rell']
# ['Skarner', 'Kalista', 'Zyra', 'Neeko', 'Orianna']
# ['Jayce', 'Sejuani', 'Ezreal', 'Corki', 'Braum']
# ['Viego', "K'Sante", 'Corki', 'Ashe', 'Poppy']
# ['Azir', 'Kalista', 'Sejuani', 'Leona', 'Jax']
# ['Zyra', 'Viktor', 'Skarner', 'Renata Glasc', 'Neeko']
# ['Rumble', 'Yone', 'Vi', 'Varus', 'Braum']
# ['Viego', "K'Sante", 'Corki', 'Ashe', 'Poppy']
# ['Azir', 'Kalista', 'Sejuani', 'Leona', 'Jax']
# ['Zyra', 'Viktor', 'Skarner', 'Renata Glasc', 'Neeko']
# ['Rumble', 'Yone', 'Vi', 'Varus', 'Braum']
# ['Poppy', 'Jayce', 'Ashe', 'Caitlyn', 'Ezreal']
# ['Viktor', 'Viego', 'Renekton', 'Miss Fortune', 'Leona']
# ['Skarner', 'Sejuani', 'Kalista', 'Azir', 'Xayah']
# ["K'Sante", 'Nocturne', 'Orianna', "Kai'Sa", 'Rakan']
# ['Poppy', 'Jayce', 'Ashe', 'Caitlyn', 'Ezreal']
# ['Viktor', 'Viego', 'Renekton', 'Miss Fortune', 'Leona']
# ['Skarner', 'Sejuani', 'Kalista', 'Azir', 'Xayah']
# ["K'Sante", 'Nocturne', 'Orianna', "Kai'Sa", 'Rakan']
# ['Kalista', 'Ambessa', 'Miss Fortune', 'Wukong', 'Neeko']
# ['Ashe', 'Maokai', 'Azir', 'Viego', 'Renata Glasc']
# ['Skarner', 'Viktor', 'Aurora', 'Leona', 'Poppy']
# ['Jhin', "K'Sante", 'Sylas', 'Xin Zhao', 'Pyke']
# ['Kalista', 'Ambessa', 'Miss Fortune', 'Wukong', 'Neeko']
# ['Ashe', 'Maokai', 'Azir', 'Viego', 'Renata Glasc']
# ['Skarner', 'Viktor', 'Aurora', 'Leona', 'Poppy']
# ['Jhin', "K'Sante", 'Sylas', 'Xin Zhao', 'Pyke']
# ['Nocturne', 'Zyra', 'Skarner', 'Poppy', "Kai'Sa"]
# ['Aurora', "K'Sante", 'Ezreal', 'Lee Sin', 'Rell']
# ['Viego', 'Viktor', 'Ashe', "Kha'Zix", 'Wukong']
# ['Orianna', 'Xin Zhao', 'Ambessa', 'Corki', 'Rakan']
# ['Nocturne', 'Zyra', 'Skarner', 'Poppy', "Kai'Sa"]
# ['Aurora', "K'Sante", 'Ezreal', 'Lee Sin', 'Rell']
# ['Viego', 'Viktor', 'Ashe', "Kha'Zix", 'Wukong']
# ['Orianna', 'Xin Zhao', 'Ambessa', 'Corki', 'Rakan']
# ["K'Sante", 'Rumble', 'Varus', 'Jax', "Kai'Sa"]
# ['Corki', 'Zyra', 'Renekton', 'Cassiopeia', 'Nautilus']
# ['Kalista', 'Skarner', 'Ambessa', 'Rell', 'Poppy']
# ['Nocturne', 'Aurora', 'Rakan', 'Ezreal', 'Jayce']
# ["K'Sante", 'Rumble', 'Varus', 'Jax', "Kai'Sa"]
# ['Corki', 'Zyra', 'Renekton', 'Cassiopeia', 'Nautilus']
# ['Kalista', 'Skarner', 'Ambessa', 'Rell', 'Poppy']
# ['Nocturne', 'Aurora', 'Rakan', 'Ezreal', 'Jayce']
# ['Zyra', 'Galio', "K'Sante", 'Miss Fortune', 'Kalista']
# ['Rumble', 'Vi', 'Yone', 'Ezreal', 'Leona']
# ['Skarner', 'Nocturne', 'Ashe', 'Not Found', 'Varus']
# ['Ambessa', 'Sejuani', 'Azir', 'Corki', 'Rell']
# ['Zyra', 'Galio', "K'Sante", 'Miss Fortune', 'Kalista']
# ['Rumble', 'Vi', 'Yone', 'Ezreal', 'Leona']
# ['Skarner', 'Nocturne', 'Ashe', 'Not Found', 'Varus']
# ['Ambessa', 'Sejuani', 'Azir', 'Corki', 'Rell']
# ['Nocturne', 'Kalista', "K'Sante", 'Rakan', 'Ashe']
# ['Varus', 'Orianna', 'Xin Zhao', 'Nautilus', 'Maokai']
# ['Zyra', 'Galio', 'Skarner', 'Jayce', 'Udyr']
# ['Viktor', 'Wukong', 'Jax', "Kai'Sa", 'Taric']
# ['Nocturne', 'Kalista', "K'Sante", 'Rakan', 'Ashe']
# ['Varus', 'Orianna', 'Xin Zhao', 'Nautilus', 'Maokai']
# ['Zyra', 'Galio', 'Skarner', 'Jayce', 'Udyr']
# ['Viktor', 'Wukong', 'Jax', "Kai'Sa", 'Taric']
# ['Rumble', "K'Sante", 'Varus', 'Yone', 'Akali']
# ['Ashe', 'Viktor', 'Viego', 'Braum', 'Maokai']
# ['Kalista', 'Skarner', 'Ambessa', 'Gragas', 'Renata Glasc']
# ['Jax', 'Sejuani', 'Jhin', 'Azir', 'Rell']
# ['Rumble', "K'Sante", 'Varus', 'Yone', 'Akali']
# ['Ashe', 'Viktor', 'Viego', 'Braum', 'Maokai']
# ['Kalista', 'Skarner', 'Ambessa', 'Gragas', 'Renata Glasc']
# ['Jax', 'Sejuani', 'Jhin', 'Azir', 'Rell']
# ['Poppy', 'Pantheon', 'Skarner', 'Kindred', 'Wukong']
# ['Viktor', 'Ambessa', 'Sejuani', 'Corki', 'Rell']
# ['Azir', 'Ashe', 'Kalista', 'Elise', 'Yone']
# ["K'Sante", 'Varus', 'Galio', 'Xin Zhao', 'Rakan']
# ['Poppy', 'Pantheon', 'Skarner', 'Kindred', 'Wukong']
# ['Viktor', 'Ambessa', 'Sejuani', 'Corki', 'Rell']
# ['Azir', 'Ashe', 'Kalista', 'Elise', 'Yone']
# ["K'Sante", 'Varus', 'Galio', 'Xin Zhao', 'Rakan']
# ['Kalista', 'Caitlyn', 'Aurora', 'Miss Fortune', 'Ezreal']
# ['Ashe', 'Jayce', 'Leona', 'Zyra', 'Yone']
# ['Nocturne', 'Skarner', 'Azir', 'Viego', 'Hwei']
# ['Rumble', 'Pantheon', 'Orianna', 'Jhin', 'Alistar']
# ['Kalista', 'Caitlyn', 'Aurora', 'Miss Fortune', 'Ezreal']
# ['Ashe', 'Jayce', 'Leona', 'Zyra', 'Yone']
# ['Nocturne', 'Skarner', 'Azir', 'Viego', 'Hwei']
# ['Rumble', 'Pantheon', 'Orianna', 'Jhin', 'Alistar']
# ['Zyra', 'Poppy', 'Varus', 'Rakan', 'Ezreal']
# ['Rumble', 'Wukong', 'Yone', "Kai'Sa", 'Taric']
# ['Skarner', 'Kalista', 'Nocturne', 'Leona', 'Renata Glasc']
# ["K'Sante", 'Vi', 'Akali', 'Ashe', 'Braum']
# ['Zyra', 'Poppy', 'Varus', 'Rakan', 'Ezreal']
# ['Rumble', 'Wukong', 'Yone', "Kai'Sa", 'Taric']
# ['Skarner', 'Kalista', 'Nocturne', 'Leona', 'Renata Glasc']
# ["K'Sante", 'Vi', 'Akali', 'Ashe', 'Braum']
# ['Viktor', 'Sejuani', 'Poppy', 'Jax', 'Gnar']
# ['Kalista', 'Renata Glasc', 'Renekton', 'Lee Sin', 'LeBlanc']
# ['Skarner', 'Zyra', 'Nocturne', 'Azir', 'Viego']
# ['Varus', 'Taliyah', 'Xin Zhao', 'Gragas', 'Elise']
# ['Viktor', 'Sejuani', 'Poppy', 'Jax', 'Gnar']
# ['Kalista', 'Renata Glasc', 'Renekton', 'Lee Sin', 'LeBlanc']
# ['Skarner', 'Zyra', 'Nocturne', 'Azir', 'Viego']
# ['Varus', 'Taliyah', 'Xin Zhao', 'Gragas', 'Elise']
# ['Poppy', 'Sejuani', 'Jayce', 'Jax', 'Irelia']
# ['Leona', 'Jhin', 'Aurora', 'Nocturne', 'Ambessa']
# ['Skarner', 'Galio', 'Zyra', 'Jinx', 'Caitlyn']
# ['Ezreal', 'Azir', 'Viego', 'Maokai', 'Alistar']
# ['Poppy', 'Sejuani', 'Jayce', 'Jax', 'Irelia']
# ['Leona', 'Jhin', 'Aurora', 'Nocturne', 'Ambessa']
# ['Skarner', 'Galio', 'Zyra', 'Jinx', 'Caitlyn']
# ['Ezreal', 'Azir', 'Viego', 'Maokai', 'Alistar']
# ['Poppy', 'Rumble', 'Xin Zhao', 'Corki', 'Ezreal']
# ["K'Sante", 'Wukong', 'Varus', 'Ahri', 'Nautilus']
# ['Skarner', 'Kalista', 'Jayce', 'Renata Glasc', 'Orianna']
# ['Ambessa', 'Vi', 'Aurora', 'Miss Fortune', 'Rell']
# ['Poppy', 'Rumble', 'Xin Zhao', 'Corki', 'Ezreal']
# ["K'Sante", 'Wukong', 'Varus', 'Ahri', 'Nautilus']
# ['Skarner', 'Kalista', 'Jayce', 'Renata Glasc', 'Orianna']
# ['Ambessa', 'Vi', 'Aurora', 'Miss Fortune', 'Rell']
# ['Nocturne', 'Rumble', 'Sejuani', 'Viego', 'Xin Zhao']
# ['Ashe', 'Zyra', 'Yone', 'Renekton', 'Braum']
# ['Skarner', 'Kalista', 'Jayce', 'Udyr', 'Leona']
# ['Viktor', 'Ezreal', 'Jax', 'Sion', 'Rakan']
# ['Nocturne', 'Rumble', 'Sejuani', 'Viego', 'Xin Zhao']
# ['Ashe', 'Zyra', 'Yone', 'Renekton', 'Braum']
# ['Skarner', 'Kalista', 'Jayce', 'Udyr', 'Leona']
# ['Viktor', 'Ezreal', 'Jax', 'Sion', 'Rakan']
# ['Poppy', 'Leona', 'Corki', 'Caitlyn', 'Jhin']
# ['Jayce', 'Kindred', 'Galio', 'Aphelios', 'Lulu']
# ['Skarner', 'Kalista', 'Sejuani', 'Renata Glasc', 'Ziggs']
# ['Orianna', 'Xin Zhao', 'Rumble', 'Jinx', 'Pyke']
# ['Poppy', 'Leona', 'Corki', 'Caitlyn', 'Jhin']
# ['Jayce', 'Kindred', 'Galio', 'Aphelios', 'Lulu']
# ['Skarner', 'Kalista', 'Sejuani', 'Renata Glasc', 'Ziggs']
# ['Orianna', 'Xin Zhao', 'Rumble', 'Jinx', 'Pyke']
# ['Rumble', 'Varus', 'Zyra', 'Leona', 'Poppy']
# ['Viktor', 'Xin Zhao', 'Ambessa', 'Miss Fortune', 'Rell']
# ['Skarner', 'Kalista', 'Ashe', "Kai'Sa", 'Caitlyn']
# ["K'Sante", 'Viego', 'Azir', 'Ezreal', 'Braum']
# ['Rumble', 'Varus', 'Zyra', 'Leona', 'Poppy']
# ['Viktor', 'Xin Zhao', 'Ambessa', 'Miss Fortune', 'Rell']
# ['Skarner', 'Kalista', 'Ashe', "Kai'Sa", 'Caitlyn']
# ["K'Sante", 'Viego', 'Azir', 'Ezreal', 'Braum']
# ['Varus', 'Skarner', 'Ashe', 'Leona', 'Nautilus']
# ['Caitlyn', 'Kindred', 'Galio', 'Jax', 'Renata Glasc']
# ['Rumble', 'Kalista', 'Jayce', 'Elise', 'Gnar']
# ['Vi', 'Aurora', 'Jhin', 'Poppy', 'Bard']
# ['Varus', 'Skarner', 'Ashe', 'Leona', 'Nautilus']
# ['Caitlyn', 'Kindred', 'Galio', 'Jax', 'Renata Glasc']
# ['Rumble', 'Kalista', 'Jayce', 'Elise', 'Gnar']
# ['Vi', 'Aurora', 'Jhin', 'Poppy', 'Bard']
# ['Varus', 'Aurora', 'Rumble', 'Akali', 'Braum']
# ["K'Sante", 'Nocturne', 'Orianna', 'Miss Fortune', 'Rell']
# ['Skarner', 'Kalista', 'Zyra', 'Ezreal', 'Poppy']
# ['Ashe', 'Sejuani', 'Ambessa', 'Azir', 'Leona']
# ['Varus', 'Aurora', 'Rumble', 'Akali', 'Braum']
# ["K'Sante", 'Nocturne', 'Orianna', 'Miss Fortune', 'Rell']
# ['Skarner', 'Kalista', 'Zyra', 'Ezreal', 'Poppy']
# ['Ashe', 'Sejuani', 'Ambessa', 'Azir', 'Leona']
# ['Kalista', 'Zyra', 'Varus', 'Braum', 'Rakan']
# ['Jayce', 'Pantheon', 'Taliyah', 'Ezreal', 'Karma']
# ['Vi', 'Skarner', 'Rumble', 'Jhin', 'Nautilus']
# ['Viego', 'Aurora', 'Irelia', 'Caitlyn', 'Elise']
# ['Kalista', 'Zyra', 'Varus', 'Braum', 'Rakan']
# ['Jayce', 'Pantheon', 'Taliyah', 'Ezreal', 'Karma']
# ['Vi', 'Skarner', 'Rumble', 'Jhin', 'Nautilus']
# ['Viego', 'Aurora', 'Irelia', 'Caitlyn', 'Elise']
# ['Poppy', "K'Sante", 'Sejuani', 'Renata Glasc', 'Ezreal']
# ['Rumble', 'Xin Zhao', 'Viktor', 'Xayah', 'Rakan']
# ['Skarner', 'Kalista', 'Vi', 'Ashe', 'Varus']
# ['Jayce', 'Pantheon', 'Akali', 'Corki', 'Nautilus']
# ['Poppy', "K'Sante", 'Sejuani', 'Renata Glasc', 'Ezreal']
# ['Rumble', 'Xin Zhao', 'Viktor', 'Xayah', 'Rakan']
# ['Skarner', 'Kalista', 'Vi', 'Ashe', 'Varus']
# ['Jayce', 'Pantheon', 'Akali', 'Corki', 'Nautilus']
# ['Sejuani', 'Zyra', 'Pantheon', 'Ashe', 'Corki']
# ['Varus', "K'Sante", 'Xin Zhao', 'Renata Glasc', 'Taliyah']
# ['Skarner', 'Kalista', 'Akali', 'Aurora', 'Orianna']
# ['Viktor', 'Vi', 'Ambessa', "Kai'Sa", 'Leona']
# ['Sejuani', 'Zyra', 'Pantheon', 'Ashe', 'Corki']
# ['Varus', "K'Sante", 'Xin Zhao', 'Renata Glasc', 'Taliyah']
# ['Skarner', 'Kalista', 'Akali', 'Aurora', 'Orianna']
# ['Viktor', 'Vi', 'Ambessa', "Kai'Sa", 'Leona']
# ['Varus', "K'Sante", 'Aurora', 'Ziggs', 'Leona']
# ['Rumble', 'Vi', 'Taliyah', 'Jinx', 'Nautilus']
# ['Skarner', 'Kalista', 'Zyra', 'Renata Glasc', 'Poppy']
# ['Ambessa', 'Sejuani', 'Yone', 'Ezreal', 'Rell']
# ['Varus', "K'Sante", 'Aurora', 'Ziggs', 'Leona']
# ['Rumble', 'Vi', 'Taliyah', 'Jinx', 'Nautilus']
# ['Skarner', 'Kalista', 'Zyra', 'Renata Glasc', 'Poppy']
# ['Ambessa', 'Sejuani', 'Yone', 'Ezreal', 'Rell']
# ['Kalista', 'Vi', 'Varus', 'Poppy', 'Braum']
# ["K'Sante", 'Viego', 'Taliyah', 'Caitlyn', 'Leona']
# ['Skarner', 'Sejuani', 'Ashe', 'Miss Fortune', "Kai'Sa"]
# ['Azir', 'Ambessa', 'Nocturne', 'Ezreal', 'Rell']
# ['Kalista', 'Vi', 'Varus', 'Poppy', 'Braum']
# ["K'Sante", 'Viego', 'Taliyah', 'Caitlyn', 'Leona']
# ['Skarner', 'Sejuani', 'Ashe', 'Miss Fortune', "Kai'Sa"]
# ['Azir', 'Ambessa', 'Nocturne', 'Ezreal', 'Rell']
# ['Aurora', 'Varus', 'Nocturne', 'Ziggs', 'Rakan']
# ['Ashe', 'Jayce', 'Braum', 'Azir', 'Wukong']
# ['Skarner', 'Kalista', 'Zyra', 'Viego', 'Viktor']
# ["K'Sante", 'Xin Zhao', 'Orianna', 'Corki', 'Leona']
# ['Aurora', 'Varus', 'Nocturne', 'Ziggs', 'Rakan']
# ['Ashe', 'Jayce', 'Braum', 'Azir', 'Wukong']
# ['Skarner', 'Kalista', 'Zyra', 'Viego', 'Viktor']
# ["K'Sante", 'Xin Zhao', 'Orianna', 'Corki', 'Leona']
# ['Sejuani', 'Zyra', 'Pantheon', 'Poppy', 'Seraphine']
# ['Rumble', 'Lee Sin', 'Ezreal', 'Rakan', 'Azir']
# ['Skarner', 'Kalista', 'Nocturne', 'LeBlanc', 'Bard']
# ['Ashe', 'Viego', 'Ornn', 'Braum', 'Hwei']
# ['Sejuani', 'Zyra', 'Pantheon', 'Poppy', 'Seraphine']
# ['Rumble', 'Lee Sin', 'Ezreal', 'Rakan', 'Azir']
# ['Skarner', 'Kalista', 'Nocturne', 'LeBlanc', 'Bard']
# ['Ashe', 'Viego', 'Ornn', 'Braum', 'Hwei']
# ['Nocturne', 'Aurora', 'Varus', 'Nidalee', 'Viego']
# ['Renekton', 'Zyra', 'Jhin', 'Rakan', 'Hwei']
# ['Skarner', 'Viktor', 'Kalista', 'Pyke', 'Blitzcrank']
# ['Jax', 'Caitlyn', 'Lux', 'Lee Sin', 'Ryze']
# ['Nocturne', 'Aurora', 'Varus', 'Nidalee', 'Viego']
# ['Renekton', 'Zyra', 'Jhin', 'Rakan', 'Hwei']
# ['Skarner', 'Viktor', 'Kalista', 'Pyke', 'Blitzcrank']
# ['Jax', 'Caitlyn', 'Lux', 'Lee Sin', 'Ryze']
# ['Viktor', 'Ambessa', 'Orianna', 'Rell', 'Ashe']
# ['Aurora', 'Wukong', 'Jayce', 'Xayah', 'Rakan']
# ['Skarner', 'Kalista', 'Rumble', 'Caitlyn', 'Varus']
# ["K'Sante", 'Vi', 'Taliyah', 'Miss Fortune', 'Poppy']
# ['Viktor', 'Ambessa', 'Orianna', 'Rell', 'Ashe']
# ['Aurora', 'Wukong', 'Jayce', 'Xayah', 'Rakan']
# ['Skarner', 'Kalista', 'Rumble', 'Caitlyn', 'Varus']
# ["K'Sante", 'Vi', 'Taliyah', 'Miss Fortune', 'Poppy']
# ['Vi', 'Nocturne', 'Skarner', 'Sejuani', 'Wukong']
# ['Viktor', 'Varus', 'Xin Zhao', 'Poppy', 'Rakan']
# ["K'Sante", 'Viego', 'Elise', 'Renekton', 'Nautilus']
# ['Kalista', 'Neeko', 'Ambessa', 'Jarvan IV', 'Sylas']
# ['Vi', 'Nocturne', 'Skarner', 'Sejuani', 'Wukong']
# ['Viktor', 'Varus', 'Xin Zhao', 'Poppy', 'Rakan']
# ["K'Sante", 'Viego', 'Elise', 'Renekton', 'Nautilus']
# ['Kalista', 'Neeko', 'Ambessa', 'Jarvan IV', 'Sylas']
# ['Ambessa', 'Orianna', 'Viktor', 'Renekton', 'Gnar']
# ['Sejuani', 'Jax', 'Ashe', 'Rell', 'Akali']
# ['Skarner', 'Kalista', 'Rumble', 'Sylas', 'Yone']
# ['Varus', 'Maokai', 'Azir', 'Xin Zhao', 'Renata Glasc']
# ['Ambessa', 'Orianna', 'Viktor', 'Renekton', 'Gnar']
# ['Sejuani', 'Jax', 'Ashe', 'Rell', 'Akali']
# ['Skarner', 'Kalista', 'Rumble', 'Sylas', 'Yone']
# ['Varus', 'Maokai', 'Azir', 'Xin Zhao', 'Renata Glasc']
# ['Ashe', 'Rumble', 'Wukong', 'Leona', 'Rell']
# ['Sejuani', 'Jax', 'Taliyah', 'Corki', 'Nautilus']
# ['Skarner', 'Jayce', "K'Sante", 'Caitlyn', 'Miss Fortune']
# ['Viego', 'Aurora', 'Gragas', "Kai'Sa", 'Alistar']
# ['Ashe', 'Rumble', 'Wukong', 'Leona', 'Rell']
# ['Sejuani', 'Jax', 'Taliyah', 'Corki', 'Nautilus']
# ['Skarner', 'Jayce', "K'Sante", 'Caitlyn', 'Miss Fortune']
# ['Viego', 'Aurora', 'Gragas', "Kai'Sa", 'Alistar']
# ['Skarner', 'Ashe', 'Nocturne', 'Xayah', 'Caitlyn']
# ['Rumble', 'Vi', 'Yone', 'Rell', 'Ziggs']
# ["K'Sante", 'Ezreal', 'Jayce', 'Miss Fortune', 'Jhin']
# ['Aatrox', 'Orianna', 'Pantheon', 'Leona', 'Sivir']
# ['Skarner', 'Ashe', 'Nocturne', 'Xayah', 'Caitlyn']
# ['Rumble', 'Vi', 'Yone', 'Rell', 'Ziggs']
# ["K'Sante", 'Ezreal', 'Jayce', 'Miss Fortune', 'Jhin']
# ['Aatrox', 'Orianna', 'Pantheon', 'Leona', 'Sivir']
# ['Vi', 'Rumble', 'Ambessa', 'Azir', 'Viktor']
# ['Jayce', 'Nidalee', 'Leona', 'Hwei', 'Zeri']
# ['Kalista', 'Caitlyn', "K'Sante", 'Varus', 'Ezreal']
# ['Corki', 'Skarner', 'Poppy', 'Maokai', 'Orianna']
# ['Vi', 'Rumble', 'Ambessa', 'Azir', 'Viktor']
# ['Jayce', 'Nidalee', 'Leona', 'Hwei', 'Zeri']
# ['Kalista', 'Caitlyn', "K'Sante", 'Varus', 'Ezreal']
# ['Corki', 'Skarner', 'Poppy', 'Maokai', 'Orianna']
# ['Zyra', 'Nocturne', 'Pantheon', 'Taliyah', 'Ambessa']
# ['Rumble', 'Rell', 'Viego', 'Ezreal', 'Azir']
# ['Kalista', 'Caitlyn', "K'Sante", 'Jhin', 'Miss Fortune']
# ['Galio', 'Vi', 'Rakan', 'Varus', 'Viktor']
# ['Zyra', 'Nocturne', 'Pantheon', 'Taliyah', 'Ambessa']
# ['Rumble', 'Rell', 'Viego', 'Ezreal', 'Azir']
# ['Kalista', 'Caitlyn', "K'Sante", 'Jhin', 'Miss Fortune']
# ['Galio', 'Vi', 'Rakan', 'Varus', 'Viktor']
# ['Sejuani', "K'Sante", 'Galio', 'Elise', 'Azir']
# ['Vi', 'Rumble', 'Aurora', 'Corki', 'Leona']
# ['Skarner', 'Kalista', 'Zyra', 'Ezreal', 'Ashe']
# ['Jayce', 'Varus', 'Xin Zhao', 'Rell', 'Taliyah']
# ['Sejuani', "K'Sante", 'Galio', 'Elise', 'Azir']
# ['Vi', 'Rumble', 'Aurora', 'Corki', 'Leona']
# ['Skarner', 'Kalista', 'Zyra', 'Ezreal', 'Ashe']
# ['Jayce', 'Varus', 'Xin Zhao', 'Rell', 'Taliyah']
# ['Sejuani', 'Nocturne', 'Ambessa', 'Pantheon', 'Wukong']
# ["K'Sante", 'Ashe', 'Elise', 'Yone', 'Karthus']
# ['Skarner', 'Kalista', 'Zyra', 'Kindred', 'Nidalee']
# ['Gnar', 'Ezreal', 'Neeko', 'Azir', 'Sion']
# ...
# ['Rumble', 'Varus', 'Xin Zhao', 'Ashe', 'Xayah']
# ['Vladimir', 'Pantheon', "Kai'Sa", 'Ryze', 'Alistar']
# ['Jayce', 'Viktor', 'Tristana', 'Taliyah', 'Sylas']
# ['Ambessa', 'Ahri', 'Skarner', 'Lucian', 'Leona']
# ['Rumble', 'Varus', 'Xin Zhao', 'Ashe', 'Xayah']
# ['Vladimir', 'Pantheon', "Kai'Sa", 'Ryze', 'Alistar']
# ['Rumble', 'Viktor', 'Neeko', 'Viego', 'Wukong']
# ['Corki', 'Lillia', 'Rell', 'Xayah', 'Nidalee']
# ['Varus', 'Xin Zhao', 'Jax', 'Tristana', 'Ashe']
# ['Hwei', 'Jhin', 'Pyke', 'Renekton', 'Vi']
# ['Rumble', 'Viktor', 'Neeko', 'Viego', 'Wukong']
# ['Corki', 'Lillia', 'Rell', 'Xayah', 'Nidalee']
# ['Varus', 'Xin Zhao', 'Jax', 'Tristana', 'Ashe']
# ['Hwei', 'Jhin', 'Pyke', 'Renekton', 'Vi']
# ['Vi', 'Nocturne', 'Yone', 'Sejuani', 'Maokai']
# ['Taliyah', 'Varus', 'Xin Zhao', 'Nautilus', 'Ambessa']
# ['Skarner', 'Kalista', 'Pantheon', 'Leona', 'Sion']
# ['Neeko', 'Jayce', 'Jhin', 'Naafiri', 'Sylas']
# ['Vi', 'Nocturne', 'Yone', 'Sejuani', 'Maokai']
# ['Taliyah', 'Varus', 'Xin Zhao', 'Nautilus', 'Ambessa']
# ['Skarner', 'Kalista', 'Pantheon', 'Leona', 'Sion']
# ['Neeko', 'Jayce', 'Jhin', 'Naafiri', 'Sylas']
# ['Taliyah', 'Kalista', 'Jayce', 'Varus', 'Ashe']
# ['Gwen', 'Trundle', 'Azir', 'Lucian', 'Braum']
# ['Naafiri', 'Yorick', 'Pantheon', 'Neeko', 'Ezreal']
# ['Sejuani', 'Rumble', 'Yone', 'Jhin', 'Nautilus']
# ['Taliyah', 'Kalista', 'Jayce', 'Varus', 'Ashe']
# ['Gwen', 'Trundle', 'Azir', 'Lucian', 'Braum']
# ['Naafiri', 'Yorick', 'Pantheon', 'Neeko', 'Ezreal']
# ['Sejuani', 'Rumble', 'Yone', 'Jhin', 'Nautilus']
# ['Rumble', 'Azir', 'Vi', 'Lucian', 'Varus']
# ['Yorick', "Kha'Zix", 'Galio', 'Draven', 'Neeko']
# ['Nidalee', 'Pantheon', 'Gwen', 'Ezreal', 'Senna']
# ['Xin Zhao', 'Taliyah', 'Aatrox', 'Kalista', 'Renata Glasc']
# ['Rumble', 'Azir', 'Vi', 'Lucian', 'Varus']
# ['Yorick', "Kha'Zix", 'Galio', 'Draven', 'Neeko']
# ['Nidalee', 'Pantheon', 'Gwen', 'Ezreal', 'Senna']
# ['Xin Zhao', 'Taliyah', 'Aatrox', 'Kalista', 'Renata Glasc']
# ['Annie', 'Nocturne', 'Xin Zhao', 'Sylas', 'Vi']
# ['Gwen', 'Pantheon', 'Ahri', 'Lucian', 'Nami']
# ['Taliyah', 'Rumble', 'Sejuani', 'Neeko', 'Jhin']
# ['Ambessa', 'Varus', 'Renata Glasc', 'Azir', 'Naafiri']
# ['Ambessa', 'Varus', 'Taliyah', 'Kennen', 'Rumble']
# ['Vi', 'Ahri', 'Miss Fortune', 'Shen', 'Ornn']
# ['Gragas', 'Yone', 'Gwen', 'Sion', 'Braum']
# ['Xin Zhao', 'Azir', 'Jhin', 'Leona', 'Aatrox']
# ['Ambessa', 'Varus', 'Taliyah', 'Kennen', 'Rumble']
# ['Vi', 'Ahri', 'Miss Fortune', 'Shen', 'Ornn']
# ['Gragas', 'Yone', 'Gwen', 'Sion', 'Braum']
# ['Xin Zhao', 'Azir', 'Jhin', 'Leona', 'Aatrox']
# ['Ivern', 'Tristana', 'Corki', "K'Sante", 'Nautilus']
# ['Varus', 'Rell', 'Taliyah', 'Renekton', 'Nidalee']
# ['Not Found', 'Not Found', 'Kindred', 'Kindred', 'Jayce']
# ['Miss Fortune', 'Yone', 'Fiddlesticks', 'Ambessa', 'Neeko']
# ['Ivern', 'Tristana', 'Corki', "K'Sante", 'Nautilus']
# ['Varus', 'Rell', 'Taliyah', 'Renekton', 'Nidalee']
# ['Not Found', 'Not Found', 'Kindred', 'Kindred', 'Jayce']
# ['Miss Fortune', 'Yone', 'Fiddlesticks', 'Ambessa', 'Neeko']
# ['Jayce', 'Rumble', 'Orianna', 'Bard', 'Gwen']
# ['Taliyah', 'Varus', "Rek'Sai", 'Braum', 'Shen']
# ['Vi', 'Xin Zhao', 'Pantheon', 'Renekton', 'Nautilus']
# ['Yone', 'Sejuani', 'Miss Fortune', 'Neeko', 'Vladimir']
# ['Jayce', 'Rumble', 'Orianna', 'Bard', 'Gwen']
# ['Taliyah', 'Varus', "Rek'Sai", 'Braum', 'Shen']
# ['Vi', 'Xin Zhao', 'Pantheon', 'Renekton', 'Nautilus']
# ['Yone', 'Sejuani', 'Miss Fortune', 'Neeko', 'Vladimir']
# ['Pantheon', 'Corki', 'Tristana', 'Xayah', 'Sivir']
# ['Ezreal', 'Xin Zhao', 'Vladimir', "K'Sante", 'Braum']
# ['Ambessa', 'Gwen', 'Naafiri', 'Poppy', 'Alistar']
# ['Vi', 'Ahri', 'Rakan', "Kai'Sa", 'Shen']
# ['Pantheon', 'Corki', 'Tristana', 'Xayah', 'Sivir']
# ['Ezreal', 'Xin Zhao', 'Vladimir', "K'Sante", 'Braum']
# ['Ambessa', 'Gwen', 'Naafiri', 'Poppy', 'Alistar']
# ['Vi', 'Ahri', 'Rakan', "Kai'Sa", 'Shen']
# ['Pantheon', 'Ivern', 'Ambessa', 'Elise', 'Bard']
# ['Varus', 'Sejuani', 'Yorick', 'Hwei', 'Alistar']
# ['Udyr', 'Shen', 'Ahri', 'Braum', 'Rell']
# ['Skarner', 'Corki', 'Fiora', 'Nautilus', 'Mel']
# ['Pantheon', 'Ivern', 'Ambessa', 'Elise', 'Bard']
# ['Varus', 'Sejuani', 'Yorick', 'Hwei', 'Alistar']
# ['Udyr', 'Shen', 'Ahri', 'Braum', 'Rell']
# ['Skarner', 'Corki', 'Fiora', 'Nautilus', 'Mel']
# ['Ivern', 'Ambessa', 'Fiddlesticks', 'Skarner', 'Corki']
# ['Yone', 'Gragas', 'Lillia', 'Tristana', 'Alistar']
# ['Not Found', 'Not Found', 'Yasuo', 'Yasuo', 'Poppy']
# ['Naafiri', 'Ahri', "K'Sante", 'Rell', "Kai'Sa"]
# ['Ivern', 'Ambessa', 'Fiddlesticks', 'Skarner', 'Corki']
# ['Yone', 'Gragas', 'Lillia', 'Tristana', 'Alistar']
# ['Not Found', 'Not Found', 'Yasuo', 'Yasuo', 'Poppy']
# ['Naafiri', 'Ahri', "K'Sante", 'Rell', "Kai'Sa"]
# ['Ivern', 'Ambessa', 'Mel', 'LeBlanc', 'Viktor']
# ['Varus', 'Pantheon', 'Taliyah', 'Jax', 'Braum']
# ['Hwei', 'Zoe', 'Tristana', 'Alistar', 'Rell']
# ['Corki', 'Wukong', 'Nautilus', 'Azir', 'Malphite']
# ['Ivern', 'Ambessa', 'Mel', 'LeBlanc', 'Viktor']
# ['Varus', 'Pantheon', 'Taliyah', 'Jax', 'Braum']
# ['Hwei', 'Zoe', 'Tristana', 'Alistar', 'Rell']
# ['Corki', 'Wukong', 'Nautilus', 'Azir', 'Malphite']
# ['Yone', 'Ambessa', 'Gwen', 'Azir', 'Ahri']
# ['Naafiri', "Kai'Sa", 'Orianna', 'Rell', 'Poppy']
# ['Vi', 'Corki', 'Pantheon', 'Sion', 'Olaf']
# ['Ezreal', 'Xin Zhao', 'Shen', 'Viktor', 'Alistar']
# ['Yone', 'Ambessa', 'Gwen', 'Azir', 'Ahri']
# ['Naafiri', "Kai'Sa", 'Orianna', 'Rell', 'Poppy']
# ['Vi', 'Corki', 'Pantheon', 'Sion', 'Olaf']
# ['Ezreal', 'Xin Zhao', 'Shen', 'Viktor', 'Alistar']
# ['Jayce', 'Yone', 'Taliyah', 'Braum', 'Karma']
# ['Ivern', "Kai'Sa", 'Mel', 'Alistar', 'Sion']
# ['Xin Zhao', 'Naafiri', 'Ambessa', 'Poppy', 'Nautilus']
# ['Vi', 'Ezreal', 'Viktor', 'Rakan', 'Gwen']
# ['Jayce', 'Yone', 'Taliyah', 'Braum', 'Karma']
# ['Ivern', "Kai'Sa", 'Mel', 'Alistar', 'Sion']
# ['Xin Zhao', 'Naafiri', 'Ambessa', 'Poppy', 'Nautilus']
# ['Vi', 'Ezreal', 'Viktor', 'Rakan', 'Gwen']
# ['Taliyah', 'Kindred', 'Lillia', 'Gwen', 'Viego']
# ['Corki', 'Sejuani', 'Syndra', 'Sion', 'Nautilus']
# ['Yorick', 'Ahri', 'Varus', 'Braum', 'Shen']
# ['Miss Fortune', 'Viktor', 'Leona', 'Vi', 'Ambessa']
# ['Taliyah', 'Kindred', 'Lillia', 'Gwen', 'Viego']
# ['Corki', 'Sejuani', 'Syndra', 'Sion', 'Nautilus']
# ['Yorick', 'Ahri', 'Varus', 'Braum', 'Shen']
# ['Miss Fortune', 'Viktor', 'Leona', 'Vi', 'Ambessa']
# ['Ezreal', 'Ambessa', 'Gwen', 'Braum', 'Sion']
# ['Naafiri', 'Lucian', 'Taliyah', "Cho'Gath", 'Leona']
# ['Maokai', 'Senna', 'Vi', 'Milio', 'Nami']
# ['Corki', 'Xin Zhao', 'Shen', 'Akali', 'Alistar']
# ['Ezreal', 'Ambessa', 'Gwen', 'Braum', 'Sion']
# ['Naafiri', 'Lucian', 'Taliyah', "Cho'Gath", 'Leona']
# ['Maokai', 'Senna', 'Vi', 'Milio', 'Nami']
# ['Corki', 'Xin Zhao', 'Shen', 'Akali', 'Alistar']
# ['Yorick', 'Ahri', 'Tristana', 'Rell', 'Rakan']
# ['Shen', 'Vi', 'Corki', 'Orianna', 'Nami']
# ['Gragas', 'Yone', 'Gwen', 'Ambessa', 'Olaf']
# ['Sejuani', 'Miss Fortune', 'Mordekaiser', 'Neeko', 'Senna']
# ['Yorick', 'Ahri', 'Tristana', 'Rell', 'Rakan']
# ['Shen', 'Vi', 'Corki', 'Orianna', 'Nami']
# ['Gragas', 'Yone', 'Gwen', 'Ambessa', 'Olaf']
# ['Sejuani', 'Miss Fortune', 'Mordekaiser', 'Neeko', 'Senna']
# ['Ivern', 'Ambessa', 'Varus', 'Xerath', 'Sylas']
# ['Senna', 'Alistar', 'Gwen', 'Mel', 'Jarvan IV']
# ['Jayce', 'Yone', 'Vi', 'Taliyah', 'Syndra']
# ['Maokai', 'Jinx', 'Leona', 'Hwei', 'Fiora']
# ['Ivern', 'Ambessa', 'Varus', 'Xerath', 'Sylas']
# ['Senna', 'Alistar', 'Gwen', 'Mel', 'Jarvan IV']
# ['Jayce', 'Yone', 'Vi', 'Taliyah', 'Syndra']
# ['Maokai', 'Jinx', 'Leona', 'Hwei', 'Fiora']
# ['Ambessa', 'Rumble', 'Skarner', 'Rell', 'Miss Fortune']
# ['Naafiri', 'Smolder', 'Sion', 'Alistar', 'Varus']
# ['Pantheon', 'Corki', 'Vi', 'Poppy', 'Ahri']
# ['Yone', 'Lillia', "K'Sante", 'Leona', 'Tristana']
# ['Ambessa', 'Rumble', 'Skarner', 'Rell', 'Miss Fortune']
# ['Naafiri', 'Smolder', 'Sion', 'Alistar', 'Varus']
# ['Pantheon', 'Corki', 'Vi', 'Poppy', 'Ahri']
# ['Yone', 'Lillia', "K'Sante", 'Leona', 'Tristana']
# ['Kindred', 'Viego', 'Vi', 'Viktor', 'Syndra']
# ['Pantheon', 'Rell', 'Tristana', 'Annie', 'Renekton']
# ['Zoe', 'Varus', 'Taliyah', 'Shen', 'Hwei']
# ['Miss Fortune', 'Xin Zhao', 'Alistar', 'Azir', 'Ornn']
# ['Kindred', 'Viego', 'Vi', 'Viktor', 'Syndra']
# ['Pantheon', 'Rell', 'Tristana', 'Annie', 'Renekton']
# ['Zoe', 'Varus', 'Taliyah', 'Shen', 'Hwei']
# ['Miss Fortune', 'Xin Zhao', 'Alistar', 'Azir', 'Ornn']
# ['Gragas', 'Yone', 'Ambessa', 'Viego', 'Xin Zhao']
# ['Vi', 'Varus', 'Neeko', 'Lux', 'Fiora']
# ['Zoe', 'Pantheon', 'Taliyah', 'Syndra', 'Hwei']
# ['Shen', 'Tristana', 'Annie', 'Wukong', 'Rell']
# ['Gragas', 'Yone', 'Ambessa', 'Viego', 'Xin Zhao']
# ['Vi', 'Varus', 'Neeko', 'Lux', 'Fiora']
# ['Zoe', 'Pantheon', 'Taliyah', 'Syndra', 'Hwei']
# ['Shen', 'Tristana', 'Annie', 'Wukong', 'Rell']
# ['Corki', 'Skarner', 'Tristana', 'Rell', 'Neeko']
# ['Naafiri', 'Taliyah', 'Shen', 'Yorick', 'Sivir']
# ['Maokai', 'Vi', 'Azir', 'Lucian', 'Miss Fortune']
# ['Lillia', 'Yone', 'Varus', "K'Sante", 'Alistar']
# ['Corki', 'Skarner', 'Tristana', 'Rell', 'Neeko']
# ['Naafiri', 'Taliyah', 'Shen', 'Yorick', 'Sivir']
# ['Maokai', 'Vi', 'Azir', 'Lucian', 'Miss Fortune']
# ['Lillia', 'Yone', 'Varus', "K'Sante", 'Alistar']
# ['Ezreal', 'Naafiri', 'Akali', 'Syndra', 'Sylas']
# ['Jayce', 'Zeri', 'Volibear', 'Gwen', 'Nautilus']
# ['Maokai', 'Senna', 'Ivern', 'Lulu', 'Milio']
# ['Jhin', 'Sejuani', 'Yorick', 'Azir', 'Rell']
# ['Ezreal', 'Naafiri', 'Akali', 'Syndra', 'Sylas']
# ['Jayce', 'Zeri', 'Volibear', 'Gwen', 'Nautilus']
# ['Maokai', 'Senna', 'Ivern', 'Lulu', 'Milio']
# ['Jhin', 'Sejuani', 'Yorick', 'Azir', 'Rell']
# ['Kindred', 'Xin Zhao', 'Varus', 'Ahri', 'Syndra']
# ['Vi', 'Ambessa', 'Taliyah', 'Ezreal', 'Alistar']
# ['Yone', 'Jayce', 'Gwen', 'Senna', 'Nautilus']
# ['Rumble', 'Miss Fortune', 'Viego', 'Viktor', 'Rell']
# ['Kindred', 'Xin Zhao', 'Varus', 'Ahri', 'Syndra']
# ['Vi', 'Ambessa', 'Taliyah', 'Ezreal', 'Alistar']
# ['Yone', 'Jayce', 'Gwen', 'Senna', 'Nautilus']
# ['Rumble', 'Miss Fortune', 'Viego', 'Viktor', 'Rell']
# ['Yorick', 'Ezreal', 'Ahri', 'Nami', 'Braum']
# ['Corki', 'Naafiri', 'Taliyah', 'Olaf', 'Nautilus']
# ['Vi', 'Pantheon', 'Varus', 'Poppy', 'Leona']
# ['Xin Zhao', 'Lucian', 'Syndra', 'Shen', 'Lulu']
# ['Yorick', 'Ezreal', 'Ahri', 'Nami', 'Braum']
# ['Corki', 'Naafiri', 'Taliyah', 'Olaf', 'Nautilus']
# ['Vi', 'Pantheon', 'Varus', 'Poppy', 'Leona']
# ['Xin Zhao', 'Lucian', 'Syndra', 'Shen', 'Lulu']
# ['Skarner', 'Tristana', 'Taliyah', 'Neeko', 'Rell']
# ['Yorick', 'Xin Zhao', 'Jhin', 'Azir', 'Nautilus']
# ['Ezreal', 'Sejuani', 'Gwen', 'Poppy', 'Alistar']
# ['Corki', 'Naafiri', 'Sion', 'Leona', 'Mel']
# ['Skarner', 'Tristana', 'Taliyah', 'Neeko', 'Rell']
# ['Yorick', 'Xin Zhao', 'Jhin', 'Azir', 'Nautilus']
# ['Ezreal', 'Sejuani', 'Gwen', 'Poppy', 'Alistar']
# ['Corki', 'Naafiri', 'Sion', 'Leona', 'Mel']
# ['Ahri', 'Ezreal', 'Yorick', 'Sion', 'Udyr']
# ['Pantheon', 'Taliyah', 'Rell', 'Senna', 'Renekton']
# ['Naafiri', 'Vi', 'Varus', 'Ashe', 'Miss Fortune']
# ['Sejuani', 'Neeko', 'Xayah', 'Braum', 'Volibear']
# ['Ahri', 'Ezreal', 'Yorick', 'Sion', 'Udyr']
# ['Pantheon', 'Taliyah', 'Rell', 'Senna', 'Renekton']
# ['Naafiri', 'Vi', 'Varus', 'Ashe', 'Miss Fortune']
# ['Sejuani', 'Neeko', 'Xayah', 'Braum', 'Volibear']
# ['Yone', 'Gragas', 'Naafiri', 'Nautilus', 'Alistar']
# ['Rumble', 'Miss Fortune', 'Skarner', 'Mel', 'Rell']
# ['Taliyah', 'Vi', 'Yorick', 'Braum', 'Orianna']
# ['Xin Zhao', 'Varus', 'Ornn', 'Ahri', 'Poppy']
# ['Yone', 'Gragas', 'Naafiri', 'Nautilus', 'Alistar']
# ['Rumble', 'Miss Fortune', 'Skarner', 'Mel', 'Rell']
# ['Taliyah', 'Vi', 'Yorick', 'Braum', 'Orianna']
# ['Xin Zhao', 'Varus', 'Ornn', 'Ahri', 'Poppy']
# ['Zoe', 'Varus', 'Tristana', 'Renekton', 'Neeko']
# ['Vi', 'Ezreal', 'Poppy', 'Braum', 'Kassadin']
# ['Naafiri', 'Pantheon', 'Corki', 'Olaf', 'Sion']
# ['Taliyah', 'Skarner', 'Miss Fortune', 'Nautilus', 'Aatrox']
# ['Zoe', 'Varus', 'Tristana', 'Renekton', 'Neeko']
# ['Vi', 'Ezreal', 'Poppy', 'Braum', 'Kassadin']
# ['Naafiri', 'Pantheon', 'Corki', 'Olaf', 'Sion']
# ['Taliyah', 'Skarner', 'Miss Fortune', 'Nautilus', 'Aatrox']
# ['Kindred', 'Miss Fortune', 'Nautilus', 'Irelia', 'Akali']
# ['Varus', 'Bard', 'Viktor', 'Tristana', 'Amumu']
# ['Ivern', 'Yone', 'Ambessa', 'Corki', 'Skarner']
# ['Rumble', 'Jhin', 'Rell', 'Mel', 'Viego']
# ["Bel'Veth", 'Vi', 'Sejuani', 'Gnar', 'Nami']
# ['Xin Zhao', 'Varus', 'Neeko', "K'Sante", 'Syndra']
# ['Rumble', 'Gwen', 'Yasuo', 'Yorick', 'Sylas']
# ['Lucian', 'Pantheon', 'Viktor', 'Sion', 'Rakan']
# ["Bel'Veth", 'Vi', 'Sejuani', 'Gnar', 'Nami']
# ['Xin Zhao', 'Varus', 'Neeko', "K'Sante", 'Syndra']
# ['Rumble', 'Gwen', 'Yasuo', 'Yorick', 'Sylas']
# ['Lucian', 'Pantheon', 'Viktor', 'Sion', 'Rakan']
# ['Lucian', 'Neeko', 'Nautilus', 'Ezreal', 'Ahri']
# ['Skarner', 'Galio', 'Bard', 'Jhin', 'Yone']
# ['Kled', "Bel'Veth", 'Pantheon', 'Hwei', 'Miss Fortune']
# ['Vi', 'Rumble', 'Rakan', 'Xayah', 'Smolder']
# ['Lucian', 'Neeko', 'Nautilus', 'Ezreal', 'Ahri']
# ['Skarner', 'Galio', 'Bard', 'Jhin', 'Yone']
# ['Kled', "Bel'Veth", 'Pantheon', 'Hwei', 'Miss Fortune']
# ['Vi', 'Rumble', 'Rakan', 'Xayah', 'Smolder']
# ['Xin Zhao', 'Vi', 'Yorick', 'Sylas', 'Leona']
# ['Jayce', 'Ezreal', 'Kindred', 'Alistar', 'Azir']
# ['Gwen', 'Taliyah', 'Lillia', 'Galio', 'Braum']
# ['Pantheon', 'Sion', "Kai'Sa", 'Nautilus', 'Akali']
# ['Xin Zhao', 'Vi', 'Yorick', 'Sylas', 'Leona']
# ['Jayce', 'Ezreal', 'Kindred', 'Alistar', 'Azir']
# ['Gwen', 'Taliyah', 'Lillia', 'Galio', 'Braum']
# ['Pantheon', 'Sion', "Kai'Sa", 'Nautilus', 'Akali']
# ['Lux', 'Yorick', 'Sion', 'Jhin', 'Ezreal']
# ['Rumble', 'Varus', 'Neeko', 'Wukong', 'Viktor']
# ['Jayce', 'Ambessa', 'Naafiri', 'Yone', 'Xin Zhao']
# ["K'Sante", 'Pantheon', 'Mel', 'Xayah', 'Akali']
# ['Lux', 'Yorick', 'Sion', 'Jhin', 'Ezreal']
# ['Rumble', 'Varus', 'Neeko', 'Wukong', 'Viktor']
# ['Jayce', 'Ambessa', 'Naafiri', 'Yone', 'Xin Zhao']
# ["K'Sante", 'Pantheon', 'Mel', 'Xayah', 'Akali']
# ['Xin Zhao', 'Vi', 'Yorick', 'Braum', 'Neeko']
# ['Varus', 'Evelynn', 'Zed', 'Nautilus', 'Shen']
# ["Rek'Sai", 'Zoe', 'Jayce', 'Olaf', 'Gnar']
# ['Naafiri', 'Taliyah', 'Lucian', 'Leona', "K'Sante"]
# ['Xin Zhao', 'Vi', 'Yorick', 'Braum', 'Neeko']
# ['Varus', 'Evelynn', 'Zed', 'Nautilus', 'Shen']
# ["Rek'Sai", 'Zoe', 'Jayce', 'Olaf', 'Gnar']
# ['Naafiri', 'Taliyah', 'Lucian', 'Leona', "K'Sante"]
# ['Vi', 'Pantheon', 'Sejuani', 'Braum', 'Akali']
# ['Varus', 'Viego', 'Jayce', 'Rell', 'Gwen']
# ["Rek'Sai", 'Evelynn', 'Nocturne', 'Leona', 'Renata Glasc']
# ['Xin Zhao', "Kai'Sa", 'Sion', 'Nautilus', 'Aurora']
# ['Vi', 'Pantheon', 'Sejuani', 'Braum', 'Akali']
# ['Varus', 'Viego', 'Jayce', 'Rell', 'Gwen']
# ["Rek'Sai", 'Evelynn', 'Nocturne', 'Leona', 'Renata Glasc']
# ['Xin Zhao', "Kai'Sa", 'Sion', 'Nautilus', 'Aurora']
# ['Sylas', 'Azir', 'Nautilus', 'Ezreal', 'Varus']
# ['Vi', 'Kalista', 'Neeko', 'Ambessa', 'Annie']
# ['Pantheon', 'Taliyah', 'Lucian', 'Ahri', 'Rumble']
# ['Xin Zhao', 'Gwen', 'Viktor', 'Ashe', 'Braum']
# ['Sylas', 'Azir', 'Nautilus', 'Ezreal', 'Varus']
# ['Vi', 'Kalista', 'Neeko', 'Ambessa', 'Annie']
# ['Pantheon', 'Taliyah', 'Lucian', 'Ahri', 'Rumble']
# ['Xin Zhao', 'Gwen', 'Viktor', 'Ashe', 'Braum']
# ['Skarner', 'Yorick', 'Hwei', 'Taliyah', 'Neeko']
# ['Vi', 'Rumble', 'Ezreal', 'Sylas', 'Braum']
# ['Lucian', 'Viktor', 'Jayce', 'Leona', 'Ahri']
# ['Varus', 'Jarvan IV', 'Galio', 'Mel', 'Bard']
# ['Skarner', 'Yorick', 'Hwei', 'Taliyah', 'Neeko']
# ['Vi', 'Rumble', 'Ezreal', 'Sylas', 'Braum']
# ['Lucian', 'Viktor', 'Jayce', 'Leona', 'Ahri']
# ['Varus', 'Jarvan IV', 'Galio', 'Mel', 'Bard']
# ['Lucian', 'Xin Zhao', 'Pantheon', 'Zoe', 'Sylas']
# ['Ashe', 'Braum', 'Gwen', 'Ahri', 'Zed']
# ['Rumble', 'Varus', 'Vi', 'Viego', 'Sejuani']
# ['Miss Fortune', 'Sion', 'Neeko', 'Wukong', 'Ekko']
# ['Lucian', 'Xin Zhao', 'Pantheon', 'Zoe', 'Sylas']
# ['Ashe', 'Braum', 'Gwen', 'Ahri', 'Zed']
# ['Rumble', 'Varus', 'Vi', 'Viego', 'Sejuani']
# ['Miss Fortune', 'Sion', 'Neeko', 'Wukong', 'Ekko']
# ['Gwen', 'Rumble', 'Jayce', 'Yasuo', 'Aatrox']
# ['Zoe', 'Caitlyn', 'Neeko', "K'Sante", 'Nocturne']
# ['Xin Zhao', 'Lucian', 'Lillia', 'Viego', 'Ambessa']
# ['Taliyah', 'Miss Fortune', 'Rell', 'Viktor', 'Gnar']
# ['Gwen', 'Rumble', 'Jayce', 'Yasuo', 'Aatrox']
# ['Zoe', 'Caitlyn', 'Neeko', "K'Sante", 'Nocturne']
# ['Xin Zhao', 'Lucian', 'Lillia', 'Viego', 'Ambessa']
# ['Taliyah', 'Miss Fortune', 'Rell', 'Viktor', 'Gnar']
# ['Lucian', 'Varus', 'Rumble', 'Tristana', 'Xayah']
# ['Wukong', 'Jax', "Kai'Sa", 'Ahri', 'Lux']
# ['Pantheon', 'Xin Zhao', 'Taliyah', 'Orianna', 'Zoe']
# ['Yorick', 'Sejuani', 'Azir', 'Corki', 'Nautilus']

# %%
for team in teams:
    db_cursor.execute(team_count, (team.name, team.year))
    if db_cursor.fetchone()[0] == 0:
        db_cursor.execute(insert_team, (team.name, team.year))
        database.commit()

# %%
for player in players:
    db_cursor.execute(team_id, (player.team.name, player.team.year))
    player_team_id = db_cursor.fetchone()[0]

    db_cursor.execute(player_count, (player.name, player_team_id))
    if db_cursor.fetchone()[0] == 0:
        db_cursor.execute(insert_player, (player.name, player_team_id))
        database.commit()

# %%
db_cursor = database.cursor()

for tournament in tournaments:
    db_cursor.execute(tournament_count, (tournament.league, tournament.year, tournament.split))
    if db_cursor.fetchone()[0] == 0:
        db_cursor.execute(insert_tournament, (tournament.league, tournament.year, tournament.split))
        database.commit()

    db_cursor.execute(tournament_id, (tournament.league, tournament.year, tournament.split))
    current_tournament_id = db_cursor.fetchone()[0]

    teams = {}
    players = {}
    for match in tournament.matches:
        db_cursor.execute(team_id, (match.teamOne.name, match.teamOne.year.item()))
        teams[match.teamOne.name] = db_cursor.fetchone()[0]
        db_cursor.execute(team_id, (match.teamTwo.name, match.teamTwo.year.item()))
        teams[match.teamTwo.name] = db_cursor.fetchone()[0]

        # print((current_tournament_id, match.date, teams[match.teamOne.name], teams[match.teamTwo.name], match.playoffs, match.patch))
        db_cursor.execute(match_count, (current_tournament_id, match.date, teams[match.teamOne.name], teams[match.teamTwo.name], match.playoffs, match.patch))
        if db_cursor.fetchone()[0] == 0:
            db_cursor.execute(insert_match, (current_tournament_id, match.date, teams[match.teamOne.name], teams[match.teamTwo.name], match.playoffs, match.patch))
            database.commit()

        db_cursor.execute(match_id, (current_tournament_id, match.date, teams[match.teamOne.name], teams[match.teamTwo.name], 
                                        match.playoffs, match.patch))
        current_match_id = db_cursor.fetchone()[0]

        for game in match.games:
            db_cursor.execute(game_count, (current_match_id, game.number.item(), teams[game.blueTeam.name], teams[game.redTeam.name], game.blueWin.item(), game.duration.item()))
            if db_cursor.fetchone()[0] == 0:
                db_cursor.execute(insert_game, (current_match_id, game.number.item(), teams[game.blueTeam.name], teams[game.redTeam.name], game.blueWin.item(), game.duration.item()))
                database.commit()

            db_cursor.execute(game_id, (current_match_id, game.number.item(), teams[game.blueTeam.name], teams[game.redTeam.name], game.blueWin.item(), game.duration.item()))
            current_game_id = db_cursor.fetchone()[0]

            db_cursor.execute(objective_count, (current_game_id, 'Blue', game.blueObjectives.firstBlood, game.blueObjectives.firstTower, game.blueObjectives.towers, game.blueObjectives.plates, game.blueObjectives.voidGrubs, game.blueObjectives.riftHeralds, game.blueObjectives.baronNashtors, game.blueObjectives.infernalDragons, game.blueObjectives.mountainDragons, game.blueObjectives.cloudDragons, game.blueObjectives.oceanDragons, game.blueObjectives.hextechDragons, game.blueObjectives.chemtechDragons, game.blueObjectives.elderDragons, game.blueObjectives.featsOfStrength, game.blueObjectives.ruinousAtakhan, game.blueObjectives.voraciousAtakan))
            if db_cursor.fetchone()[0] == 0:
                db_cursor.execute(insert_objective, (current_game_id, 'Blue', game.blueObjectives.firstBlood, game.blueObjectives.firstTower, game.blueObjectives.towers, game.blueObjectives.plates, game.blueObjectives.voidGrubs, game.blueObjectives.riftHeralds, game.blueObjectives.baronNashtors, game.blueObjectives.infernalDragons, game.blueObjectives.mountainDragons, game.blueObjectives.cloudDragons, game.blueObjectives.oceanDragons, game.blueObjectives.hextechDragons, game.blueObjectives.chemtechDragons, game.blueObjectives.elderDragons, game.blueObjectives.featsOfStrength, game.blueObjectives.ruinousAtakhan, game.blueObjectives.voraciousAtakan))
                database.commit()

            db_cursor.execute(objective_count, (current_game_id, 'Red', game.redObjectives.firstBlood, game.redObjectives.firstTower, game.redObjectives.towers, game.redObjectives.plates, game.redObjectives.voidGrubs, game.redObjectives.riftHeralds, game.redObjectives.baronNashtors, game.redObjectives.infernalDragons, game.redObjectives.mountainDragons, game.redObjectives.cloudDragons, game.redObjectives.oceanDragons, game.redObjectives.hextechDragons, game.redObjectives.chemtechDragons, game.redObjectives.elderDragons, game.redObjectives.featsOfStrength, game.redObjectives.ruinousAtakhan, game.redObjectives.voraciousAtakan))
            if db_cursor.fetchone()[0] == 0:
                db_cursor.execute(insert_objective, (current_game_id, 'Red', game.redObjectives.firstBlood, game.redObjectives.firstTower, game.redObjectives.towers, game.redObjectives.plates, game.redObjectives.voidGrubs, game.redObjectives.riftHeralds, game.redObjectives.baronNashtors, game.redObjectives.infernalDragons, game.redObjectives.mountainDragons, game.redObjectives.cloudDragons, game.redObjectives.oceanDragons, game.redObjectives.hextechDragons, game.redObjectives.chemtechDragons, game.redObjectives.elderDragons, game.redObjectives.featsOfStrength, game.redObjectives.ruinousAtakhan, game.redObjectives.voraciousAtakan))
                database.commit()

            db_cursor.execute(pick_ban_count, (current_game_id, 'Blue', game.bluePickBan.ban1, game.bluePickBan.ban2, game.bluePickBan.ban3, game.bluePickBan.ban4, game.bluePickBan.ban5, game.bluePickBan.pick1, game.bluePickBan.pick2, game.bluePickBan.pick3, game.bluePickBan.pick4, game.bluePickBan.pick5))
            if db_cursor.fetchone()[0] == 0:
                db_cursor.execute(insert_pick_ban, (current_game_id, 'Blue', game.bluePickBan.ban1, game.bluePickBan.ban2, game.bluePickBan.ban3, game.bluePickBan.ban4, game.bluePickBan.ban5, game.bluePickBan.pick1, game.bluePickBan.pick2, game.bluePickBan.pick3, game.bluePickBan.pick4, game.bluePickBan.pick5))
                database.commit()

            db_cursor.execute(pick_ban_count, (current_game_id, 'Red', game.redPickBan.ban1, game.redPickBan.ban2, game.redPickBan.ban3, game.redPickBan.ban4, game.redPickBan.ban5, game.redPickBan.pick1, game.redPickBan.pick2, game.redPickBan.pick3, game.redPickBan.pick4, game.redPickBan.pick5))
            if db_cursor.fetchone()[0] == 0:
                db_cursor.execute(insert_pick_ban, (current_game_id, 'Red', game.redPickBan.ban1, game.redPickBan.ban2, game.redPickBan.ban3, game.redPickBan.ban4, game.redPickBan.ban5, game.redPickBan.pick1, game.redPickBan.pick2, game.redPickBan.pick3, game.redPickBan.pick4, game.redPickBan.pick5))
                database.commit()
            
            for player in game.bluePlayerPerformances:
                # print((player.player.name, teams[player.player.team.name]))
                db_cursor.execute(player_id, (player.player.name, teams[player.player.team.name]))
                players[player.player.name] = db_cursor.fetchone()[0]

                db_cursor.execute(player_performance_count, (current_game_id, players[player.player.name], player.role, player.champion, player.kills, player.deaths, player.assists, player.damageToChampions, player.wardsPlaced, player.wardsKilled, player.controlWardsBought, player.visionScore, player.totalGold, player.goldSpent, player.creepScore, player.killsAt15, player.deathsAt15, player.assistsAt15, player.goldAt15))
                if db_cursor.fetchone()[0] == 0:
                    db_cursor.execute(insert_player_performance, (current_game_id, players[player.player.name], player.role, player.champion, player.kills, player.deaths, player.assists, player.damageToChampions, player.wardsPlaced, player.wardsKilled, player.controlWardsBought, player.visionScore, player.totalGold, player.goldSpent, player.creepScore, player.killsAt15, player.deathsAt15, player.assistsAt15, player.goldAt15))
                    database.commit()

            for player in game.redPlayerPerformances:
                db_cursor.execute(player_id, (player.player.name, teams[player.player.team.name]))
                players[player.player.name] = db_cursor.fetchone()[0]

                db_cursor.execute(player_performance_count, (current_game_id, players[player.player.name], player.role, player.champion, player.kills, player.deaths, player.assists, player.damageToChampions, player.wardsPlaced, player.wardsKilled, player.controlWardsBought, player.visionScore, player.totalGold, player.goldSpent, player.creepScore, player.killsAt15, player.deathsAt15, player.assistsAt15, player.goldAt15))
                if db_cursor.fetchone()[0] == 0:
                    # print(current_game_id, players[player.player.name], player.player.name)
                    db_cursor.execute(insert_player_performance, (current_game_id, players[player.player.name], player.role, player.champion, player.kills, player.deaths, player.assists, player.damageToChampions, player.wardsPlaced, player.wardsKilled, player.controlWardsBought, player.visionScore, player.totalGold, player.goldSpent, player.creepScore, player.killsAt15, player.deathsAt15, player.assistsAt15, player.goldAt15))
                    database.commit()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[50], line 16
#      14 for match in tournament.matches:
#      15     db_cursor.execute(team_id, (match.teamOne.name, match.teamOne.year.item()))
# ---> 16     teams[match.teamOne.name] = db_cursor.fetchone()[0]
#      17     db_cursor.execute(team_id, (match.teamTwo.name, match.teamTwo.year.item()))
#      18     teams[match.teamTwo.name] = db_cursor.fetchone()[0]
#
# TypeError: 'NoneType' object is not subscriptable

# %% [markdown]
# #### Champion

# %%
insert_champion = """INSERT INTO champion (champion_name, champion_true_name, champion_id, champion_title) Values (%s, %s, %s, %s)"""
get_champion = """SELECT count(*) FROM champion WHERE champion_name = %s"""

# %%
import requests

db_cursor = database.cursor()

# URL of the JSON data
url = 'https://ddragon.leagueoflegends.com/cdn/15.8.1/data/en_US/champion.json'

# Fetch the JSON data from the URL
response = requests.get(url)

# Check if the request was successful
if response.status_code == 200:
    data = response.json()  # Parse the JSON data
    # print(data)             # Print the data
    print(data['data'])
else:
    print(f"Failed to retrieve data: {response.status_code}")

for champion in data['data']:
    print(champion)
    print(data['data'][champion]['key'])
    print(data['data'][champion]['title'])

    db_cursor.execute(get_champion, (champion, ))
    count = db_cursor.fetchone()[0]

    if count == 0:
        db_cursor.execute(insert_champion, (champion, champion, data['data'][champion]['key'], data['data'][champion]['title']))
        database.commit()
# Out:
# {'Aatrox': {'version': '15.8.1', 'id': 'Aatrox', 'key': '266', 'name': 'Aatrox', 'title': 'the Darkin Blade', 'blurb': 'Once honored defenders of Shurima against the Void, Aatrox and his brethren would eventually become an even greater threat to Runeterra, and were defeated only by cunning mortal sorcery. But after centuries of imprisonment, Aatrox was the first to find...', 'info': {'attack': 8, 'defense': 4, 'magic': 3, 'difficulty': 4}, 'image': {'full': 'Aatrox.png', 'sprite': 'champion0.png', 'group': 'champion', 'x': 0, 'y': 0, 'w': 48, 'h': 48}, 'tags': ['Fighter'], 'partype': 'Blood Well', 'stats': {'hp': 650, 'hpperlevel': 114, 'mp': 0, 'mpperlevel': 0, 'movespeed': 345, 'armor': 38, 'armorperlevel': 4.8, 'spellblock': 32, 'spellblockperlevel': 2.05, 'attackrange': 175, 'hpregen': 3, 'hpregenperlevel': 0.5, 'mpregen': 0, 'mpregenperlevel': 0, 'crit': 0, 'critperlevel': 0, 'attackdamage': 60, 'attackdamageperlevel': 5, 'attackspeedperlevel': 2.5, 'attackspeed': 0.651}}, 'Ahri': {'version': '15.8.1', 'id': 'Ahri', 'key': '103', 'name': 'Ahri', 'title': 'the Nine-Tailed Fox', 'blurb': "Innately connected to the magic of the spirit realm, Ahri is a fox-like vastaya who can manipulate her prey's emotions and consume their essence—receiving flashes of their memory and insight from each soul she consumes. Once a powerful yet wayward...", 'info': {'attack': 3, 'defense': 4, 'magic': 8, 'difficulty': 5}, 'image': {'full': 'Ahri.png', 'sprite': 'champion0.png', 'group': 'champion', 'x': 48, 'y': 0, 'w': 48, 'h': 48}, 'tags': ['Mage', 'Assassin'], 'partype': 'Mana', 'stats': {'hp': 590, 'hpperlevel': 104, 'mp': 418, 'mpperlevel': 25, 'movespeed': 330, 'armor': 21, 'armorperlevel': 4.2, 'spellblock': 30, 'spellblockperlevel': 1.3, 'attackrange': 550, 'hpregen': 2.5, 'hpregenperlevel': 0.6, 'mpregen': 8, 'mpregenperlevel': 0.8, 'crit': 0, 'critperlevel': 0, 'attackdamage': 53, 'attackdamageperlevel': 3, 'attackspeedperlevel': 2.2, 'attackspeed': 0.668}}, 'Akali': {'version': '15.8.1', 'id': 'Akali', 'key': '84', 'name': 'Akali', 'title': 'the Rogue Assassin', 'blurb': 'Abandoning the Kinkou Order and her title of the Fist of Shadow, Akali now strikes alone, ready to be the deadly weapon her people need. Though she holds onto all she learned from her master Shen, she has pledged to defend Ionia from its enemies, one...', 'info': {'attack': 5, 'defense': 3, 'magic': 8, 'difficulty': 7}, 'image': {'full': 'Akali.png', 'sprite': 'champion0.png', 'group': 'champion', 'x': 96, 'y': 0, 'w': 48, 'h': 48}, 'tags': ['Assassin'], 'partype': 'Energy', 'stats': {'hp': 600, 'hpperlevel': 119, 'mp': 200, 'mpperlevel': 0, 'movespeed': 345, 'armor': 23, 'armorperlevel': 4.7, 'spellblock': 37, 'spellblockperlevel': 2.05, 'attackrange': 125, 'hpregen': 9, 'hpregenperlevel': 0.9, 'mpregen': 50, 'mpregenperlevel': 0, 'crit': 0, 'critperlevel': 0, 'attackdamage': 62, 'attackdamageperlevel': 3.3, 'attackspeedperlevel': 3.2, 'attackspeed': 0.625}}, 'Akshan': {'version': '15.8.1', 'id': 'Akshan', 'key': '166', 'name': 'Akshan', 'title': 'the Rogue Sentinel', 'blurb': 'Raising an eyebrow in the face of danger, Akshan fights evil with dashing charisma, righteous vengeance, and a conspicuous lack of shirts. He is highly skilled in the art of stealth combat, able to evade the eyes of his enemies and reappear when they...', 'info': {'attack': 0, 'defense': 0, 'magic': 0, 'difficulty': 0}, 'image': {'full': 'Akshan.png', 'sprite': 'champion0.png', 'group': 'champion', 'x': 144, 'y': 0, 'w': 48, 'h': 48}, 'tags': ['Marksman', 'Assassin'], 'partype': 'Mana', 'stats': {'hp': 630, 'hpperlevel': 107, 'mp': 350, 'mpperlevel': 40, 'movespeed': 330, 'armor': 26, 'armorperlevel': 4.7, 'spellblock': 30, 'spellblockperlevel': 1.3, 'attackrange': 500, 'hpregen': 3.75, 'hpregenperlevel': 0.65, 'mpregen': 8.2, 'mpregenperlevel': 0.7, 'crit': 0, 'critperlevel': 0, 'attackdamage': 52, 'attackdamageperlevel': 3, 'attackspeedperlevel': 4, 'attackspeed': 0.638}}, 'Alistar': {'ver ...
# Aatrox
# 266
# the Darkin Blade
# Ahri
# 103
# the Nine-Tailed Fox
# Akali
# 84
# the Rogue Assassin
# Akshan
# 166
# the Rogue Sentinel
# Alistar
# 12
# the Minotaur
# Ambessa
# 799
# Matriarch of War
# Amumu
# 32
# the Sad Mummy
# Anivia
# 34
# the Cryophoenix
# Annie
# 1
# the Dark Child
# Aphelios
# 523
# the Weapon of the Faithful
# Ashe
# 22
# the Frost Archer
# AurelionSol
# 136
# The Star Forger
# Aurora
# 893
# the Witch Between Worlds
# Azir
# 268
# the Emperor of the Sands
# Bard
# 432
# the Wandering Caretaker
# Belveth
# 200
# the Empress of the Void
# Blitzcrank
# 53
# the Great Steam Golem
# Brand
# 63
# the Burning Vengeance
# Braum
# 201
# the Heart of the Freljord
# Briar
# 233
# the Restrained Hunger
# Caitlyn
# 51
# the Sheriff of Piltover
# Camille
# 164
# the Steel Shadow
# Cassiopeia
# 69
# the Serpent's Embrace
# Chogath
# 31
# the Terror of the Void
# Corki
# 42
# the Daring Bombardier
# Darius
# 122
# the Hand of Noxus
# Diana
# 131
# Scorn of the Moon
# Draven
# 119
# the Glorious Executioner
# DrMundo
# 36
# the Madman of Zaun
# Ekko
# 245
# the Boy Who Shattered Time
# Elise
# 60
# the Spider Queen
# Evelynn
# 28
# Agony's Embrace
# Ezreal
# 81
# the Prodigal Explorer
# Fiddlesticks
# 9
# the Ancient Fear
# Fiora
# 114
# the Grand Duelist
# Fizz
# 105
# the Tidal Trickster
# Galio
# 3
# the Colossus
# Gangplank
# 41
# the Saltwater Scourge
# Garen
# 86
# The Might of Demacia
# Gnar
# 150
# the Missing Link
# Gragas
# 79
# the Rabble Rouser
# Graves
# 104
# the Outlaw
# Gwen
# 887
# The Hallowed Seamstress
# Hecarim
# 120
# the Shadow of War
# Heimerdinger
# 74
# the Revered Inventor
# Hwei
# 910
# the Visionary
# Illaoi
# 420
# the Kraken Priestess
# Irelia
# 39
# the Blade Dancer
# Ivern
# 427
# the Green Father
# Janna
# 40
# the Storm's Fury
# JarvanIV
# 59
# the Exemplar of Demacia
# Jax
# 24
# Grandmaster at Arms
# Jayce
# 126
# the Defender of Tomorrow
# Jhin
# 202
# the Virtuoso
# Jinx
# 222
# the Loose Cannon
# Kaisa
# 145
# Daughter of the Void
# Kalista
# 429
# the Spear of Vengeance
# Karma
# 43
# the Enlightened One
# Karthus
# 30
# the Deathsinger
# Kassadin
# 38
# the Void Walker
# Katarina
# 55
# the Sinister Blade
# Kayle
# 10
# the Righteous
# Kayn
# 141
# the Shadow Reaper
# Kennen
# 85
# the Heart of the Tempest
# Khazix
# 121
# the Voidreaver
# Kindred
# 203
# The Eternal Hunters
# Kled
# 240
# the Cantankerous Cavalier
# KogMaw
# 96
# the Mouth of the Abyss
# KSante
# 897
# the Pride of Nazumah
# Leblanc
# 7
# the Deceiver
# LeeSin
# 64
# the Blind Monk
# Leona
# 89
# the Radiant Dawn
# Lillia
# 876
# the Bashful Bloom
# Lissandra
# 127
# the Ice Witch
# Lucian
# 236
# the Purifier
# Lulu
# 117
# the Fae Sorceress
# Lux
# 99
# the Lady of Luminosity
# Malphite
# 54
# Shard of the Monolith
# Malzahar
# 90
# the Prophet of the Void
# Maokai
# 57
# the Twisted Treant
# MasterYi
# 11
# the Wuju Bladesman
# Mel
# 800
# the Soul's Reflection
# Milio
# 902
# The Gentle Flame
# MissFortune
# 21
# the Bounty Hunter
# MonkeyKing
# 62
# the Monkey King
# Mordekaiser
# 82
# the Iron Revenant
# Morgana
# 25
# the Fallen
# Naafiri
# 950
# the Hound of a Hundred Bites
# Nami
# 267
# the Tidecaller
# Nasus
# 75
# the Curator of the Sands
# Nautilus
# 111
# the Titan of the Depths
# Neeko
# 518
# the Curious Chameleon
# Nidalee
# 76
# the Bestial Huntress
# Nilah
# 895
# the Joy Unbound
# Nocturne
# 56
# the Eternal Nightmare
# Nunu
# 20
# the Boy and His Yeti
# Olaf
# 2
# the Berserker
# Orianna
# 61
# the Lady of Clockwork
# Ornn
# 516
# The Fire below the Mountain
# Pantheon
# 80
# the Unbreakable Spear
# Poppy
# 78
# Keeper of the Hammer
# Pyke
# 555
# the Bloodharbor Ripper
# Qiyana
# 246
# Empress of the Elements
# Quinn
# 133
# Demacia's Wings
# Rakan
# 497
# The Charmer
# Rammus
# 33
# the Armordillo
# RekSai
# 421
# the Void Burrower
# Rell
# 526
# the Iron Maiden
# Renata
# 888
# the Chem-Baroness
# Renekton
# 58
# the Butcher of the Sands
# Rengar
# 107
# the Pridestalker
# Riven
# 92
# the Exile
# Rumble
# 68
# the Mechanized Menace
# Ryze
# 13
# the Rune Mage
# Samira
# 360
# the Desert Rose
# Sejuani
# 113
# Fury of the North
# Senna
# 235
# the Redeemer
# Seraphine
# 147
# the Starry-Eyed Songstress
# Sett
# 875
# the Boss
# Shaco
# 35
# the Demon Jester
# Shen
# 98
# the Eye of Twilight
# Shyvana
# 102
# the Half-Dragon
# Singed
# 27
# the Mad Chemist
# Sion
# 14
# The Undead Juggernaut
# Sivir
# 15
# the Battle Mistress
# Skarner
# 72
# the Primordial Sovereign
# Smolder
# 901
# the Fiery Fledgling
# Sona
# 37
# Maven of the Strings
# Soraka
# 16
# the Starchild
# Swain
# 50
# the Noxian Grand General
# Sylas
# 517
# the Unshackled
# Syndra
# 134
# the Dark Sovereign
# TahmKench
# 223
# The River King
# Taliyah
# 163
# the Stoneweaver
# Talon
# 91
# the Blade's Shadow
# Taric
# 44
# the Shield of Valoran
# Teemo
# 17
# the Swift Scout
# Thresh
# 412
# the Chain Warden
# Tristana
# 18
# the Yordle Gunner
# Trundle
# 48
# the Troll King
# Tryndamere
# 23
# the Barbarian King
# TwistedFate
# 4
# the Card Master
# Twitch
# 29
# the Plague Rat
# Udyr
# 77
# the Spirit Walker
# Urgot
# 6
# the Dreadnought
# Varus
# 110
# the Arrow of Retribution
# Vayne
# 67
# the Night Hunter
# Veigar
# 45
# the Tiny Master of Evil
# Velkoz
# 161
# the Eye of the Void
# Vex
# 711
# the Gloomist
# Vi
# 254
# the Piltover Enforcer
# Viego
# 234
# The Ruined King
# Viktor
# 112
# the Herald of the Arcane
# Vladimir
# 8
# the Crimson Reaper
# Volibear
# 106
# the Relentless Storm
# Warwick
# 19
# the Uncaged Wrath of Zaun
# Xayah
# 498
# the Rebel
# Xerath
# 101
# the Magus Ascendant
# XinZhao
# 5
# the Seneschal of Demacia
# Yasuo
# 157
# the Unforgiven
# Yone
# 777
# the Unforgotten
# Yorick
# 83
# Shepherd of Souls
# Yuumi
# 350
# the Magical Cat
# Zac
# 154
# the Secret Weapon
# Zed
# 238
# the Master of Shadows
# Zeri
# 221
# The Spark of Zaun
# Ziggs
# 115
# the Hexplosives Expert
# Zilean
# 26
# the Chronokeeper
# Zoe
# 142
# the Aspect of Twilight
# Zyra
# 143
# Rise of the Thorns
